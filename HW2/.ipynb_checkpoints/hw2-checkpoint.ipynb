# %% [markdown]
# Mount Google Drive (optional)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# import os
# # os.chdir("/content/drive/MyDrive/....")  # file path
# print(os.getcwd())

# %% [markdown]
# # **HW2 : Decision Tree and Random Forest**
# In *assignment 2*, you need to finish :
#
# 1. Basic Part : Implement a **Decision Tree** model and predict whether the patients in the validation set have diabetes
# > * Step 1 : Load the input data
# > * Step 2 : Calculate the Entropy and Information Gain
# > * Step 3 : Find the Best Split
# > * Step 4 : Split into 2 branches
# > * Step 5 : Build decision tree
# > * Step 6 : Save the answers from step2 to step5
# > * Step 7 : Split data into training set and validation set
# > * Step 8 : Train a decision tree model with training set
# > * Step 9 : Predict the cases in the *validation set* by using the model trained in *Step8*
# > * Step 10 : Calculate the f1-score of your predictions in *Step9*
# > * Step 11 : Write the Output File
#
# 2. Advanced Part : Build a **Random Forest** model to make predictions
# > * Step 1 : Load the input data
# > * Step 2 : Load the test data
# > * Step 3 : Build a random forest
# > * Step 4 : Predict the cases in the test data by using the model trained in *Step3*
# > * Step 5 : Save the predictions(from *Step 4*) in a csv file

# %% [markdown]
# # **Basic Part** (60%)
# In this part, your need to implement a Decision Tree model by completing the following given functions.
#
# Also, you need to run these functions with the given input variables and save the output in a csv file **hw2_basic.csv**

# %% [markdown]
# ## Import Packages
#
#
# > Note : You **cannot** import any other packages in both basic part and advanced part

# %%
import numpy as np
import pandas as pd
import math
import random
from numpy import sqrt
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Step1: Load the input data
# First, load the input file **hw2_input_basic.csv**

# %%
input_data = pd.read_csv('hw2_input_basic.csv')
input_data
# Out:
#      age        bmi  gender  height  weight  glucose_apache  \
# 0   70.0  25.984659       1   172.7   77.50           116.0
# 1   30.0  31.310368       1   170.2   90.70            71.0
# 2   54.0  24.388824       1   177.8   77.10           120.0
# 3   65.0  34.141074       0   170.2   98.90            73.0
# 4   49.0  22.564743       1   172.7   67.30           207.0
# 5   62.0  29.424010       0   154.9   70.60           113.0
# 6   85.0  27.673574       1   154.9   66.40           102.0
# 7   65.0  22.269432       1   177.8   70.40           333.0
# 8   85.0  35.879362       0   165.1   97.80           124.0
# 9   81.0  20.859375       0   160.0   53.40           136.0
# 10  59.0  46.409136       0   162.6  122.70           169.0
# 11  77.0  32.324734       0   154.9   77.56           264.0
# 12  68.0  15.913579       1   185.4   54.70            39.0
# 13  51.0  24.028492       1   190.5   87.20            80.0
# 14  76.0  34.216873       0   154.9   82.10           306.0
# 15  48.0  26.516476       1   180.3   86.20            96.0
# 16  82.0  18.921389       0   154.9   45.40           164.0
# 17  78.0  36.668167       0   167.6  103.00           282.0
# 18  62.0  19.108088       1   157.5   47.40           275.0
# 19  73.0  22.851562       0   160.0   58.50           178.0
# 20  73.0  20.351971       0   167.5   57.10           159.0
# 21  59.0  27.109238       1   177.8   85.70            85.0
# 22  51.0  37.954367       0   172.7  113.20           168.0
# 23  80.0  36.267895       1   180.3  117.90           138.0
# 24  74.0  25.856081       1   170.2   74.90           145.0
# 25  61.0  29.161972       1   180.3   94.80           267.0
# 26  74.0  38.111136       1   188.0  134.70           279.0
# 27  65.0  53.414791       0   166.4  147.90           121.0
# 28  38.0  33.438787       0   161.3   87.00           135.0
# 29  82.0  32.263238       0   162.6   85.30           111.0
#
#     heart_rate_apache  resprate_apache  sodium_apache  diabetes_mellitus
# 0               101.0             49.0          137.0                  0
# 1                39.0             33.0          144.0                  0
# 2               120.0             31.0          141.0                  0
# 3                48.0             36.0          140.0                  1
# 4               119.0              6.0          144.0                  0
# 5                60.0             32.0          137.0                  0
# 6                49.0             36.0          142.0                  0
# 7                59.0              6.0          145.0                  1
# 8                92.0             30.0          136.0                  0
# 9               118.0             52.0          138.0                  0
# 10              100.0             46.0          138.0                  0
# 11               90.0             37.0          141.0                  1
# 12              108.0             45.0          135.0                  0
# 13               61.0             30.0          139.0                  0
# 14              112.0             40.0          130.0                  1
# 15              133.0             31.0          137.0                  0
# 16              103.0             48.0          134.0                  0
# 17              104.0             42.0          138.0                  1
# 18              108.0             38.0          131.0                  1
# 19              154.0             55.0          138.0                  1
# 20              110.0             27.0          139.0                  0
# 21               92.0              6.0          143.0                  0
# 22               60.0             43.0          119.0                  1
# 23              178.0             43.0          140.0                  1
# 24               40.0             16.0          146.0                  1
# 25               62.0             58.0          134.0                  1
# 26              112.0             43.0          132.0                  1
# 27               88.0             32.0          142.0                  0
# 28               46.0             28.0          138.0                  0
# 29              114.0             22.0          143.0                  1

# %% [markdown]
# ## Global attributes
# Define the global attributes
# > Note : You **cannot** modify the values of these attributes we given in the basic part

# %%
max_depth = 2
depth = 0
min_samples_split = 2
n_features = input_data.shape[1] - 1

# %% [markdown]
# > You can add your own global attributes here

# %% [markdown]
# ## Step2 : Calculate the Entropy and Information Gain
# Calculate the information gain and entropy values before separate data into left subtree and right subtree

# %%
def entropy(data):
  """
  This function measures the amount of uncertainty in a probability distribution
  args: 
  * data(type: DataFrame): the data you're calculating for the entropy
  return:
  * entropy_value(type: float): the data's entropy
  """
  
  total = 0
  size = len(data)
  if(size == 0):
    return 0
  for i in range(size):
    if(data.loc[i, "diabetes_mellitus"] == 1):
      total += 1
  rate = total/size
  if(rate == 0 or rate == 1):
    return 0 
  entropy_value = -rate * math.log2(rate) - (1-rate) * math.log2(1-rate)
  return entropy_value

# [Note] You have to save the value of "ans_entropy" into the output file
ans_entropy = entropy(input_data)
print("ans_entropy = ", ans_entropy)
# Out:
# ans_entropy =  0.9871377743721863

# %%
def information_gain(data, mask):
  """
  This function will calculate the information gain
  args:
  * data(type: DataFrame): the data you're calculating for the information gain
  * mask(type: Series): partition information(left/right) of current input data, 
    - boolean 1(True) represents split to left subtree
    - boolean 0(False) represents split to right subtree
  return:
  * ig(type: float): the information gain you can obtain by classify data with this given mask
  """
  
  left = pd.DataFrame()
  right = pd.DataFrame()
  for i in range(data.shape[0]):
    if(mask[i] == True):
      left = pd.concat([left, data.iloc[[i]]], ignore_index=True)
    else:
      right = pd.concat([right, data.iloc[[i]]], ignore_index=True)
 
  
  ig = entropy(data) - len(left)/(len(left) + len(right)) * entropy(left) - len(right)/(len(left) + len(right)) * entropy(right)
  
  return ig
  
# [Note] You have to save the value of "ans_informationGain" into your output file
temp1 = np.zeros((int(input_data.shape[0]/4), 1), dtype=bool)
temp2 = np.ones(((input_data.shape[0]-int(input_data.shape[0]/4), 1)), dtype=bool)
temp_mask = np.concatenate((temp1, temp2))
df_mask = pd.DataFrame(temp_mask, columns=['mask'])
ans_informationGain = information_gain(input_data, df_mask['mask'])
print("ans_informationGain = ", ans_informationGain)
# Out:
# ans_informationGain =  0.08345988684807157

# %% [markdown]
# ## Step3 : Find the Best Split
# Find the best split combination, **feature** and **threshold**, by calculating the information gain

# %%
def find_best_split(data):
  """
  This function will find the best split combination of data
  args:
  * data(type: DataFrame): the input data
  return
  * best_ig(type: float): the best information gain you obtain
  * best_threshold(type: float): the value that splits data into 2 branches
  * best_feature(type: string): the feature that splits data into 2 branches
  """
  temp = pd.DataFrame()
  ig = 0
  best_threshold = 0
  best_feature = 0
  threshold = 0
  all_true = sum(data["diabetes_mellitus"])
  ori_ig = entropy(data)
  for i in range(len(data.columns)-1):
        
    if(~data[data.columns[i]].isin([0,1]).all()):
      left = 0
      temp = data[[data.columns[i] , "diabetes_mellitus" ]]
      temp1 = temp.sort_values(temp.columns[0], ascending = True)
      
      temp1.reset_index(drop=True, inplace= True)
      for j in range(1,len(data)):
        if(temp1[data.columns[i]][j] != temp1[data.columns[i]][j-1]):
          threshold = (temp1[data.columns[i]][j] + temp1[data.columns[i]][j-1] ) / 2
          temp2 = np.ones((j, 1), dtype=bool)
          temp3 = np.zeros((len(data) - j, 1), dtype=bool)
          temp_mask = np.concatenate((temp2, temp3))
          df_mask = pd.DataFrame(temp_mask, columns=['mask'])
          # t = information_gain(temp1, df_mask['mask'])
          left += temp1["diabetes_mellitus"].iat[j-1]
          right = all_true - left
          fa_en = lambda rate: 0 if (rate == 1 or rate == 0) else -rate * math.log2(rate) - (1-rate) * math.log2(1-rate)
          t = ori_ig - (j/temp1.shape[0]) * fa_en(left/j) - ((temp1.shape[0]-j)/temp1.shape[0]) * fa_en(right/(temp1.shape[0]-j))
          if(t > ig):
            ig = t
            best_threshold = threshold
            best_feature = data.columns[i]
        else:
            left += temp1["diabetes_mellitus"].iat[j-1]
            continue
    
    else:
      temp = data[[data.columns[i] , "diabetes_mellitus" ]]
      temp1 = temp.sort_values(temp.columns[0], ascending = True)
      temp1.reset_index(drop=True, inplace= True)
      
      t = information_gain(temp1, temp1[data.columns[i]])
      if(t > ig):
        ig = t
        best_threshold = threshold
        best_feature = data.columns[i]
  best_ig = ig
  return best_ig, best_threshold, best_feature


# [Note] You have to save the value of "ans_ig", "ans_value", and "ans_name" into the output file
ans_ig, ans_value, ans_name = find_best_split(input_data)


print("ans_ig = ", ans_ig)
print("ans_value = ", ans_value)
print("ans_name = ", ans_name)
# Out:
# ans_ig =  0.3522950515812332
# ans_value =  235.5
# ans_name =  glucose_apache

# %% [markdown]
# ## Step4 : Split into 2 branches
# Using the best split combination you find in function *find_best_split()* to split data into Left Subtree and Right Subtree

# %%
def make_partition(data, feature, threshold):
  """
  This function will split the data into 2 branches
  args:
  * data(type: DataFrame): the input data
  * feature(type: string): the attribute(column name)
  * threshold(type: float): the threshold for splitting the data
  return:
  * left(type: DataFrame): the divided data that matches(less than or equal to) the assigned feature's threshold
  * right(type: DataFrame): the divided data that doesn't match the assigned feature's threshold
  """
  
  left = pd.DataFrame()
  right = pd.DataFrame()
  
  for i in range(data.shape[0]):
    
    if(data[feature].iloc[i] <= threshold):
      left = pd.concat([left, data.iloc[[i]]], ignore_index=True)
    else:
      right = pd.concat([right, data.iloc[[i]]], ignore_index=True)
      
  return left, right


# [Note] You have to save the value of "ans_left" into the output file
left, right = make_partition(input_data, 'age', 61.0)
ans_left = left.shape[0]
print("ans_left = ", ans_left)
# Out:
# ans_left =  10

# %% [markdown]
# ## Step5 : Build Decision Tree
# Use the above functions to implement the decision tree
#
# Instructions:
# 1.  If current depth < max_depth and the remaining number of samples > min_samples_split: continue to classify those samples
# 2.  Use function *find_best_split()* to find the best split combination
# 3.  If the obtained information gain is **greater than 0**: can build a deeper decision tree (add depth)
# 4. Use function *make_partition()* to split the data into two parts
# 5. Save the features and corresponding thresholds (starting from the root) used by the decision tree into *ans_features[]* and *ans_thresholds[]* respectively

# %%
def build_tree(data, max_depth, min_samples_split, depth):
  """
  This function will build the decision tree
  args:
  * data(type: DataFrame): the data you want to apply to the decision tree
  * max_depth: the maximum depth of a decision tree
  * min_samples_split: the minimum number of instances required to do partition
  * depth: the height of the current decision tree
  return:
  * subtree: the decision tree structure including root, branch, and leaf (with the attributes and thresholds)
  """

  # check the condition of current depth and the remaining number of samples
  if depth < max_depth and len(data) > min_samples_split:
    # call find_best_split() to find the best combination
    ans_ig, threshold, feature = find_best_split(data)
    # check the value of information gain is greater than 0 or not 
    if ans_ig > 0 :
      # update the depth
      depth += 1
      # call make_partition() to split the data into two parts
      left_tree, right_tree = make_partition(data, feature, threshold)
      # If there is no data split to the left tree OR no data split to the left tree
      if left_tree.shape[0] == 0 or right_tree.shape[0] == 0:
        # return the label of the majority
        if(sum(data["diabetes_mellitus" ]) >= len(data)/2):
          label = 1
        else:
          label = 0
        return label
      else:
        question = "{} {} {}".format(feature, "<=", threshold)
        subtree = {question: []}
        ans_features.append(feature)
        ans_thresholds.append(threshold)
        # call function build_tree() to recursively build the left subtree and right subtree
        left_subtree = build_tree(left_tree, max_depth, min_samples_split, depth)
        right_subtree = build_tree(right_tree, max_depth, min_samples_split, depth)
        if left_subtree == right_subtree:
          subtree = left_subtree
        else:
          subtree[question].append(left_subtree)
          subtree[question].append(right_subtree)
    else:
      # return the label of the majority
      if(sum(data["diabetes_mellitus" ]) >= len(data)/2):
          label = 1
      else:
          label = 0
      return label
  else:
    # return the label of the majority
    if(sum(data["diabetes_mellitus" ]) >= len(data)/2):
      label = 1
    else:
      label = 0
    return label

  return subtree

# %% [markdown]
# An example of the output from *build_tree()*
# ```
# {'bmi <= 33.5': [1, {'age <= 68.5': [0, 1]}]}
# ```
# Therefore,
# ```
# ans_features = ['bmi', 'age']
# ans_thresholds = [33.5, 68.5]
# ```

# %%
ans_features = []
ans_thresholds = []

decisionTree = build_tree(input_data, max_depth, min_samples_split, depth)
decisionTree
# Out:
# {'glucose_apache <= 235.5': [{'heart_rate_apache <= 143.5': [0, 1]}, 1]}

# %%
# [Note] You have to save the features in the "decisionTree" structure (from root to branch and leaf) into the output file
ans_features
# Out:
# ['glucose_apache', 'heart_rate_apache']

# %%
# [Note] You have to save the corresponding thresholds for the features in the "ans_features" list into the output file
ans_thresholds
# Out:
# [235.5, 143.5]

# %% [markdown]
# ## Step6 : Save answers

# %%
basic = []
basic.append(ans_entropy)
basic.append(ans_informationGain)
basic.append(ans_ig)
basic.append(ans_value)
basic.append(ans_name)
basic.append(ans_left)
for i in range(len(ans_features)):
  basic.append(ans_features[i])
for m in range(len(ans_thresholds)):
  basic.append(ans_thresholds[m])

# %% [markdown]
# ## Step7 : Split data
# Split data into training set and validation set
# > Note: We have split the data into training set and validation. You **cannot** change the distribution of the data.

# %%
num_train = 20
num_validation = 10

training_data = input_data.iloc[:num_train]
validation_data = input_data.iloc[-num_validation:]

y_train = training_data[["diabetes_mellitus"]]
x_train = training_data.drop(['diabetes_mellitus'], axis=1)
y_validation = validation_data[["diabetes_mellitus"]]
x_validation = validation_data.drop(['diabetes_mellitus'], axis=1)
y_validation = y_validation.values.flatten()

print(input_data.shape)
print(training_data.shape)
print(validation_data.shape)
# Out:
# (30, 10)
# (20, 10)
# (10, 10)

# %% [markdown]
# ## Step8 to Step10 : Make predictions with a decision tree

# %% [markdown]
# Define the attributions of the decision tree
# > You **cannot** modify the values of these attributes in this part

# %%
max_depth = 2
depth = 0
n_features = x_train.shape[1]

# %% [markdown]
# We have finished the function '*classify_data()*' below, however, you can modify this function if you prefer completing it on your own way.

# %%
def classify_data(instance, tree):
  """
  This function will predict/classify the input instance
  args:
  * instance: a instance(case) to be predicted
  return:
  * answer: the prediction result (the classification result)
  """
  
  equation = list(tree.keys())[0] 
  if equation.split()[1] == '<=':
    temp_feature = equation.split()[0]
    temp_threshold = equation.split()[2]
    if instance[temp_feature] > float(temp_threshold):
      answer = tree[equation][1]
    else:
      answer = tree[equation][0]
  else:
    if instance[equation.split()[0]] in (equation.split()[2]):
      answer = tree[equation][0]
    else:
      answer = tree[equation][1]

  if not isinstance(answer, dict):
    return answer
  else:
    return classify_data(instance, answer)


def make_prediction(tree, data):
  """
  This function will use your pre-trained decision tree to predict the labels of all instances in data
  args:
  * tree: the decision tree
  * data: the data to predict
  return:
  * y_prediction: the predictions
  """
  y_prediction = []
  for i in range(data.shape[0]):
    y_prediction.append(classify_data(data.iloc[i], tree))
  # [Note] You can call the function classify_data() to predict the label of each instance


  return y_prediction


def calculate_score(y_true, y_pred):
  """
  This function will calculate the f1-score of the predictions
  args:
  * y_true: the ground truth
  * y_pred: the predictions
  return:
  * score: the f1-score
  """
  score = f1_score(y_true,y_pred)
  
  return score

# %%
decision_tree = build_tree(training_data, max_depth, min_samples_split, depth)

y_pred = make_prediction(decision_tree, x_validation)

# [Note] You have to save the value of "ans_f1score" the your output file
ans_f1score = calculate_score(y_validation, y_pred)
print("ans_f1score = ", ans_f1score)
# Out:
# ans_f1score =  0.6666666666666666

# %% [markdown]
# ## Step11 : Write the Output File
# Save all of your answers in a csv file, named as **hw2_basic.csv**

# %%
ans_path = 'hw2_basic.csv'

# [Note] You have to save the value of "ans_f1score" into the output file
basic.append(ans_f1score)
print(basic)

pd.DataFrame(basic).to_csv(ans_path, header = None, index = None)
# Out:
# [0.9871377743721863, 0.08345988684807157, 0.3522950515812332, 235.5, 'glucose_apache', 10, 'glucose_apache', 'heart_rate_apache', 235.5, 143.5, 0.6666666666666666]

# %% [markdown]
# # **Advanced Part** (35%)

# %% [markdown]
# ## Step1: Load the input data
# First, load the input file **hw2_input_advanced.csv**

# %%
advanced_data = pd.read_csv('hw2_input_advanced.csv')
print(advanced_data.shape[0])
# Out:
# 8379

# %% [markdown]
# You can split *advanced_data* into training set and validaiton set

# %%
data_size = advanced_data.shape[0]
num_train = 6000
num_validation = data_size - num_train

training_data = advanced_data.iloc[:num_train]
validation_data = advanced_data.iloc[-num_validation:]

y_train = training_data[["diabetes_mellitus"]]
x_train = training_data.drop(['diabetes_mellitus'], axis=1)
y_validation = validation_data[["diabetes_mellitus"]]
x_validation = validation_data.drop(['diabetes_mellitus'], axis=1)
y_validation = y_validation.values.flatten()

print(advanced_data.shape)
print(training_data.shape)
print(validation_data.shape)
# Out:
# (8379, 25)
# (6000, 25)
# (2379, 25)

# %% [markdown]
# ## Step2 : Load the test data
# Load the input file **hw2_input_test.csv** to make predictions with the pre-trained random forest model

# %%
x_test = pd.read_csv('hw2_input_test.csv')
x_test
# Out:
#      age        bmi  gender  height  weight  arf_apache  bun_apache  \
# 0     62  32.866392       1  177.80   103.9           1        31.0
# 1     82  23.582766       0  157.50    58.5           0        26.0
# 2     61  31.684520       1  172.70    94.5           0        16.0
# 3     58  45.156250       0  160.00   115.6           0        19.0
# 4     74  25.817016       1  172.70    77.0           0        25.0
# ..   ...        ...     ...     ...     ...         ...         ...
# 835   73  17.943584       0  157.48    44.5           0        12.0
# 836   79  29.049732       1  167.60    81.6           0        48.0
# 837   85  24.627827       0  152.40    57.2           0        11.0
# 838   68  32.510940       1  193.00   121.1           0        14.0
# 839   48  24.106828       0  157.50    59.8           0         7.0
#
#      creatinine_apache  gcs_eyes_apache  gcs_motor_apache  ...  \
# 0                10.30                4                 6  ...
# 1                 0.54                3                 4  ...
# 2                 1.11                4                 6  ...
# 3                 0.70                1                 4  ...
# 4                 0.93                4                 6  ...
# ..                 ...              ...               ...  ...
# 835               0.30                4                 6  ...
# 836               2.19                4                 6  ...
# 837               0.48                3                 5  ...
# 838               0.64                4                 6  ...
# 839               0.33                4                 6  ...
#
#      hematocrit_apache  intubated_apache  map_apache  resprate_apache  \
# 0                 36.4                 0         157               26
# 1                 32.8                 0          42               25
# 2                 35.3                 0         129                6
# 3                 30.1                 1         131               23
# 4                 34.5                 0          55               12
# ..                 ...               ...         ...              ...
# 835               33.8                 0         129                9
# 836               42.7                 0         163                9
# 837               29.5                 0          67                9
# 838               37.5                 0          61               10
# 839               32.3                 0         111               14
#
#      sodium_apache  temp_apache  ventilated_apache  wbc_apache  \
# 0              134         36.1                  0        4.56
# 1              142         36.1                  0        6.00
# 2              131         36.8                  0        8.59
# 3              138         34.9                  1       16.03
# 4              135         36.3                  0       45.80
# ..             ...          ...                ...         ...
# 835            144         36.9                  0        7.70
# 836            139         36.4                  0       10.77
# 837            139         36.6                  0        7.35
# 838            140         36.9                  1       16.02
# 839            139         36.3                  0        2.20
#
#      apache_4a_hospital_death_prob  apache_4a_icu_death_prob
# 0                             0.06                      0.03
# 1                             0.14                      0.06
# 2                             0.05                      0.03
# 3                             0.33                      0.22
# 4                             0.12                      0.05
# ..                             ...                       ...
# 835                           0.02                      0.01
# 836                           0.06                      0.03
# 837                           0.16                      0.05
# 838                           0.00                      0.00
# 839                           0.01                      0.00
#
# [840 rows x 24 columns]

# %% [markdown]
# ## Step3 : Build a Random Forest

# %% [markdown]
# Define the attributions of the random forest
# > * You **can** modify the values of these attributes in advanced part
# > * Each tree can have different attribute values
# > * There must be **at least** 3 decision trees in the random forest model
# > * Must use function *build_tree()* to build a random forest model
# > * These are the parameters you can adjust :
#
#
#     ```
#     max_depth =
#     depth = 0
#     min_samples_split =
#
#     # total number of trees in a random forest
#     n_trees =
#
#     # number of features to train a decision tree
#     n_features =
#
#     # the ratio to select the number of instances
#     sample_size =
#     n_samples = int(training_data.shape[0] * sample_size)
#     ```

# %%
# Define the attributes

max_depth = 5
depth = 0
min_samples_split = 10

# total number of trees in a random forest
n_trees = 550

# number of features to train a decision tree
n_features = 13

# the ratio to select the number of instances
sample_size = 0.1
n_samples = int(training_data.shape[0] * sample_size)
'''def build_tree(data, max_depth, min_samples_split, depth):'''
# Out:
# 'def build_tree(data, max_depth, min_samples_split, depth):'

# %%
def build_forest(data, n_trees, n_features, n_samples):
  a = [*range(24)]
  """
  This function will build a random forest.
  args:
  * data: all data that can be used to train a random forest
  * n_trees: total number of tree
  * n_features: number of features
  * n_samples: number of instances
  return:
  * forest: a random forest with 'n_trees' of decision tree
  """
  
  forest = []
  for i in range(n_trees):
    new_data = pd.DataFrame()
    new_data = data.sample(n=n_samples)
    new_data_tree = pd.DataFrame()
    b = random.sample(a,k=n_features)
    for j in range(len(b)):
      new_data_tree[data.columns[b[j]]] = new_data[data.columns[b[j]]]
    new_data_tree["diabetes_mellitus"] = new_data["diabetes_mellitus"]
    new_data_tree = new_data_tree.reset_index(drop=True)
    
    tree = build_tree(new_data_tree, max_depth, min_samples_split, depth)
    if(tree != 0 and tree != 1):
      forest.append(tree)
      print(tree)
  return forest

# %%
forest = build_forest(training_data, n_trees, n_features, n_samples)
forest
# Out:
# {'resprate_apache <= 31.5': [{'height <= 162.57999999999998': [{'map_apache <= 116.5': [{'creatinine_apache <= 0.85': [{'hematocrit_apache <= 28.65': [0, 1]}, {'height <= 144.75': [0, 1]}]}, {'hematocrit_apache <= 35.15': [1, 0]}]}, {'ventilated_apache <= 0': [{'sodium_apache <= 143.5': [0, {'hematocrit_apache <= 24.35': [1, 0]}]}, {'bmi <= 39.79607': [1, {'map_apache <= 162.0': [1, 0]}]}]}]}, {'creatinine_apache <= 1.82': [{'hematocrit_apache <= 30.4': [{'bmi <= 20.098325465000002': [0, {'creatinine_apache <= 1.4449999999999998': [1, 0]}]}, {'creatinine_apache <= 0.635': [{'bmi <= 21.780193904999997': [0, 1]}, 0]}]}, {'bmi <= 21.88347572': [0, {'height <= 170.05': [{'hematocrit_apache <= 23.8': [1, 0]}, {'sodium_apache <= 141.5': [1, 0]}]}]}]}]}
# {'bun_apache <= 13.5': [{'creatinine_apache <= 0.725': [{'bmi <= 22.46707403': [{'creatinine_apache <= 0.695': [0, 1]}, {'creatinine_apache <= 0.45999999999999996': [1, {'creatinine_apache <= 0.71': [0, 1]}]}]}, {'temp_apache <= 36.05': [1, 0]}]}, {'creatinine_apache <= 3.85': [{'bmi <= 27.04320044': [{'creatinine_apache <= 0.61': [{'intubated_apache <= 0.565': [1, 0]}, 0]}, {'weight <= 130.05': [{'map_apache <= 112.0': [1, 0]}, {'bun_apache <= 21.5': [1, 0]}]}]}, {'creatinine_apache <= 4.845000000000001': [1, {'weight <= 79.19999999999999': [0, {'map_apache <= 45.5': [0, 1]}]}]}]}]}
# {'glucose_apache <= 164.5': [{'resprate_apache <= 13.5': [{'hematocrit_apache <= 28.700000000000003': [{'hematocrit_apache <= 24.8': [{'creatinine_apache <= 0.73': [0, 1]}, 1]}, 0]}, 0]}, {'resprate_apache <= 41.5': [{'temp_apache <= 34.5': [0, {'apache_4a_hospital_death_prob <= -0.5': [0, {'creatinine_apache <= 10.575': [1, 0]}]}]}, {'creatinine_apache <= 0.395': [1, {'apache_4a_icu_death_prob <= 0.27': [{'temp_apache <= 36.150000000000006': [1, 0]}, {'resprate_apache <= 55.5': [1, 0]}]}]}]}]}
# {'wbc_apache <= 6.645': [{'heart_rate_apache <= 105.5': [{'weight <= 91.15': [{'heart_rate_apache <= 68.5': [0, {'wbc_apache <= 6.1': [1, 0]}]}, {'bun_apache <= 48.5': [{'age <= 76.5': [1, 0]}, 0]}]}, {'age <= 50.5': [0, {'age <= 54.5': [1, 0]}]}]}, {'bun_apache <= 26.5': [{'creatinine_apache <= 0.665': [{'height <= 167.3': [1, {'creatinine_apache <= 0.565': [1, 0]}]}, {'age <= 43.5': [{'height <= 157.45': [1, 0]}, 0]}]}, {'weight <= 77.75': [{'gcs_motor_apache <= 2.5': [1, {'age <= 59.5': [1, 0]}]}, {'wbc_apache <= 14.8': [{'creatinine_apache <= 2.645': [1, 0]}, {'age <= 85.5': [1, 0]}]}]}]}]}
# {'resprate_apache <= 15.0': [{'bun_apache <= 12.5': [{'age <= 56.5': [0, {'height <= 183.45': [{'apache_4a_icu_death_prob <= 0.015': [0, 1]}, 1]}]}, {'hematocrit_apache <= 38.25': [{'weight <= 71.4': [{'height <= 165.05': [1, 0]}, 1]}, {'weight <= 95.03': [{'bun_apache <= 17.0': [1, 0]}, {'weight <= 122.1': [0, 1]}]}]}]}, {'weight <= 64.9': [{'apache_4a_icu_death_prob <= 0.16': [{'temp_apache <= 35.45': [1, 0]}, 0]}, {'bun_apache <= 27.5': [0, {'resprate_apache <= 24.5': [{'weight <= 74.19999999999999': [1, 0]}, {'age <= 60.5': [0, 1]}]}]}]}]}
# {'bun_apache <= 18.5': [{'map_apache <= 67.5': [{'age <= 62.5': [{'wbc_apache <= 6.4': [0, {'wbc_apache <= 23.5': [1, 0]}]}, {'bmi <= 39.365790675': [{'age <= 87.5': [1, 0]}, 0]}]}, {'bmi <= 27.698156015000002': [{'map_apache <= 139.5': [0, {'age <= 64.0': [0, 1]}]}, {'gcs_eyes_apache <= 3.5': [1, {'bmi <= 29.4638592': [1, 0]}]}]}]}, {'gcs_motor_apache <= 2.0': [1, {'gcs_eyes_apache <= 1.5': [{'wbc_apache <= 18.9': [{'bun_apache <= 21.0': [1, 0]}, 1]}, {'age <= 86.5': [{'weight <= 60.5': [0, 1]}, {'heart_rate_apache <= 121.0': [0, 1]}]}]}]}]}
# {'glucose_apache <= 171.0': [{'glucose_apache <= 95.5': [{'gcs_verbal_apache <= 1.5': [{'hematocrit_apache <= 28.9': [1, {'gcs_motor_apache <= 5.5': [0, 1]}]}, {'glucose_apache <= 69.5': [1, 0]}]}, {'weight <= 91.19999999999999': [{'hematocrit_apache <= 36.35': [0, {'gcs_motor_apache <= 1.5': [1, 0]}]}, {'apache_4a_icu_death_prob <= 0.005': [0, {'temp_apache <= 36.150000000000006': [1, 0]}]}]}]}, {'wbc_apache <= 13.850000000000001': [1, {'sodium_apache <= 128.5': [0, {'hematocrit_apache <= 42.849999999999994': [{'temp_apache <= 39.3': [1, 0]}, 0]}]}]}]}
# {'hematocrit_apache <= 38.25': [{'wbc_apache <= 3.05': [0, {'weight <= 68.65': [{'heart_rate_apache <= 121.5': [{'hematocrit_apache <= 28.25': [1, 0]}, 0]}, {'gcs_verbal_apache <= 1.5': [{'map_apache <= 40.5': [0, 1]}, 1]}]}]}, {'apache_4a_icu_death_prob <= 0.52': [{'map_apache <= 109.0': [{'wbc_apache <= 15.15': [{'hematocrit_apache <= 38.5': [0, 1]}, 0]}, {'heart_rate_apache <= 106.0': [0, {'bmi <= 41.880962935': [0, 1]}]}]}, 0]}]}
# {'bmi <= 22.52655313': [{'bun_apache <= 40.5': [{'weight <= 39.25': [1, 0]}, {'gcs_motor_apache <= 5.5': [1, {'heart_rate_apache <= 90.0': [1, 0]}]}]}, {'hematocrit_apache <= 38.2': [{'bun_apache <= 16.5': [{'bmi <= 22.76075136': [1, 0]}, {'heart_rate_apache <= 127.5': [1, {'bun_apache <= 34.5': [1, 0]}]}]}, {'bun_apache <= 27.5': [{'heart_rate_apache <= 149.0': [0, 1]}, {'hematocrit_apache <= 40.1': [0, 1]}]}]}]}
# {'glucose_apache <= 164.5': [{'glucose_apache <= 81.5': [{'creatinine_apache <= 4.945': [1, 0]}, 0]}, {'glucose_apache <= 257.5': [{'sodium_apache <= 129.5': [0, {'creatinine_apache <= 5.345000000000001': [1, 0]}]}, {'wbc_apache <= 24.549999999999997': [1, 0]}]}]}
# {'glucose_apache <= 200.5': [{'resprate_apache <= 15.0': [{'height <= 159.0': [1, {'weight <= 73.4': [{'apache_4a_hospital_death_prob <= 0.035': [0, 1]}, {'apache_4a_icu_death_prob <= 0.37': [1, 0]}]}]}, {'glucose_apache <= 75.5': [{'weight <= 61.2': [0, {'resprate_apache <= 26.5': [0, 1]}]}, {'glucose_apache <= 153.0': [0, {'creatinine_apache <= 0.6799999999999999': [1, 0]}]}]}]}, {'apache_4a_hospital_death_prob <= 0.605': [{'weight <= 158.10000000000002': [1, 0]}, {'temp_apache <= 33.45': [1, {'apache_4a_hospital_death_prob <= 0.845': [0, 1]}]}]}]}
# {'glucose_apache <= 152.5': [{'glucose_apache <= 73.5': [{'bmi <= 32.709154095': [{'heart_rate_apache <= 130.0': [{'heart_rate_apache <= 115.5': [0, 1]}, 0]}, 1]}, {'bmi <= 24.1073673': [{'glucose_apache <= 113.0': [{'sodium_apache <= 126.5': [1, 0]}, 0]}, {'gcs_verbal_apache <= 1.5': [{'gcs_motor_apache <= 5.5': [0, 1]}, 0]}]}]}, {'glucose_apache <= 186.5': [{'gcs_motor_apache <= 4.5': [0, 1]}, 1]}]}
# {'glucose_apache <= 175.5': [{'glucose_apache <= 86.5': [{'weight <= 114.9': [{'gcs_eyes_apache <= 3.5': [{'apache_4a_icu_death_prob <= 0.36': [1, 0]}, {'glucose_apache <= 68.5': [1, 0]}]}, 1]}, {'map_apache <= 135.5': [{'creatinine_apache <= 0.48': [1, {'glucose_apache <= 165.0': [0, 1]}]}, 0]}]}, {'map_apache <= 102.0': [{'apache_4a_icu_death_prob <= 0.255': [{'glucose_apache <= 206.5': [{'weight <= 71.2': [0, 1]}, 1]}, {'gcs_eyes_apache <= 2.5': [0, 1]}]}, {'resprate_apache <= 41.5': [{'bun_apache <= 18.5': [{'glucose_apache <= 197.0': [0, 1]}, {'weight <= 100.8': [0, 1]}]}, 0]}]}]}
# {'glucose_apache <= 192.5': [{'resprate_apache <= 15.5': [{'age <= 46.5': [0, {'weight <= 118.2': [0, {'apache_4a_icu_death_prob <= 0.005': [0, 1]}]}]}, {'glucose_apache <= 166.5': [{'age <= 49.5': [0, {'glucose_apache <= 71.5': [1, 0]}]}, {'resprate_apache <= 33.5': [{'wbc_apache <= 7.6': [0, 1]}, {'gcs_motor_apache <= 3.5': [1, 0]}]}]}]}, {'resprate_apache <= 15.5': [{'wbc_apache <= 12.05': [{'apache_4a_icu_death_prob <= 0.35500000000000004': [1, 0]}, 1]}, {'glucose_apache <= 235.0': [{'apache_4a_icu_death_prob <= 0.23500000000000001': [{'gcs_eyes_apache <= 3.5': [1, 0]}, 0]}, {'gender <= 0.8200000000000001': [{'apache_4a_icu_death_prob <= 0.015': [0, 1]}, {'weight <= 135.65': [1, 0]}]}]}]}]}
# {'glucose_apache <= 169.0': [{'bun_apache <= 39.5': [{'bmi <= 30.162399715': [{'resprate_apache <= 11.5': [{'glucose_apache <= 78.0': [1, 0]}, 0]}, {'bmi <= 30.471732255': [1, 0]}]}, {'glucose_apache <= 77.0': [1, {'glucose_apache <= 157.0': [0, 1]}]}]}, {'wbc_apache <= 20.95': [{'glucose_apache <= 220.0': [{'bmi <= 22.644471145': [{'glucose_apache <= 171.5': [1, 0]}, 1]}, 1]}, {'temp_apache <= 35.849999999999994': [0, {'resprate_apache <= 41.5': [{'resprate_apache <= 24.5': [0, 1]}, {'glucose_apache <= 364.5': [0, 1]}]}]}]}]}
# {'resprate_apache <= 31.5': [{'creatinine_apache <= 6.225': [{'apache_4a_hospital_death_prob <= 0.065': [{'weight <= 103.05000000000001': [{'creatinine_apache <= 0.54': [1, 0]}, 1]}, {'apache_4a_hospital_death_prob <= 0.325': [{'wbc_apache <= 21.9': [1, 0]}, {'apache_4a_hospital_death_prob <= 0.42500000000000004': [0, 1]}]}]}, {'height <= 153.75': [1, 0]}]}, {'creatinine_apache <= 0.52': [{'wbc_apache <= 3.05': [0, 1]}, {'bun_apache <= 19.5': [{'hematocrit_apache <= 30.45': [{'weight <= 96.2': [0, 1]}, 0]}, {'height <= 158.15': [{'hematocrit_apache <= 37.2': [1, 0]}, {'age <= 87.5': [0, 1]}]}]}]}]}
# {'resprate_apache <= 39.5': [{'bmi <= 27.164694335': [{'map_apache <= 51.5': [{'bmi <= 23.893797955': [{'temp_apache <= 36.55': [1, 0]}, {'sodium_apache <= 130.0': [0, 1]}]}, {'creatinine_apache <= 0.605': [{'apache_4a_icu_death_prob <= 0.12': [1, 0]}, 0]}]}, {'map_apache <= 64.5': [{'temp_apache <= 36.650000000000006': [{'hematocrit_apache <= 37.45': [1, 0]}, {'temp_apache <= 36.76': [0, 1]}]}, {'map_apache <= 154.5': [0, 1]}]}]}, {'creatinine_apache <= 2.01': [{'hematocrit_apache <= 28.85': [{'map_apache <= 149.0': [{'weight <= 67.64': [0, 1]}, 1]}, {'weight <= 75.15': [0, {'hematocrit_apache <= 44.05': [0, 1]}]}]}, {'temp_apache <= 36.650000000000006': [{'map_apache <= 164.0': [{'map_apache <= 54.5': [0, 1]}, 0]}, 1]}]}]}
# {'glucose_apache <= 172.0': [{'resprate_apache <= 43.5': [{'hematocrit_apache <= 36.3': [{'resprate_apache <= 13.5': [{'bmi <= 25.87300119': [0, 1]}, 0]}, {'bun_apache <= 33.5': [{'creatinine_apache <= 0.6799999999999999': [1, 0]}, 1]}]}, {'hematocrit_apache <= 31.35': [{'bmi <= 54.33288442': [0, 1]}, 0]}]}, {'resprate_apache <= 40.5': [{'creatinine_apache <= 10.16': [{'heart_rate_apache <= 55.0': [{'glucose_apache <= 210.0': [1, 0]}, 1]}, 0]}, {'height <= 179.05': [{'apache_4a_hospital_death_prob <= 0.035': [0, {'bmi <= 26.646222405000003': [0, 1]}]}, {'apache_4a_icu_death_prob <= 0.015': [1, 0]}]}]}]}
# {'glucose_apache <= 161.5': [{'resprate_apache <= 12.5': [{'glucose_apache <= 69.0': [1, {'bmi <= 20.966779940000002': [0, {'apache_4a_hospital_death_prob <= 0.10500000000000001': [0, 1]}]}]}, {'map_apache <= 43.5': [{'resprate_apache <= 39.5': [1, 0]}, {'bun_apache <= 19.5': [{'height <= 143.5': [1, 0]}, 0]}]}]}, {'bun_apache <= 102.5': [{'glucose_apache <= 198.5': [{'resprate_apache <= 32.5': [{'height <= 182.84': [1, 0]}, 0]}, {'resprate_apache <= 43.5': [1, {'glucose_apache <= 290.5': [0, 1]}]}]}, 0]}]}
# {'hematocrit_apache <= 33.75': [1, {'bmi <= 29.76371244': [{'age <= 75.5': [{'age <= 56.5': [0, {'map_apache <= 159.0': [0, 1]}]}, {'temp_apache <= 35.5': [1, {'bmi <= 29.06659346': [0, 1]}]}]}, {'age <= 32.5': [0, {'bmi <= 30.010133155': [1, {'gcs_motor_apache <= 2.0': [1, 0]}]}]}]}]}
# {'resprate_apache <= 14.5': [{'hematocrit_apache <= 42.400000000000006': [{'weight <= 174.15': [1, 0]}, {'weight <= 111.0': [0, 1]}]}, 0]}
# {'glucose_apache <= 176.5': [{'hematocrit_apache <= 34.05': [{'weight <= 81.85': [{'glucose_apache <= 75.5': [1, {'glucose_apache <= 154.5': [0, 1]}]}, {'glucose_apache <= 86.0': [{'apache_4a_icu_death_prob <= 0.16499999999999998': [1, 0]}, {'temp_apache <= 36.25': [1, 0]}]}]}, {'map_apache <= 190.5': [{'height <= 148.60000000000002': [1, 0]}, 1]}]}, {'glucose_apache <= 220.5': [{'map_apache <= 44.5': [1, {'apache_4a_icu_death_prob <= 0.39': [{'weight <= 75.55': [0, 1]}, 0]}]}, {'weight <= 60.725': [{'glucose_apache <= 273.5': [1, {'weight <= 53.150000000000006': [1, 0]}]}, 1]}]}]}
# {'age <= 39.5': [{'age <= 31.5': [{'heart_rate_apache <= 105.0': [0, {'resprate_apache <= 39.0': [{'resprate_apache <= 23.5': [0, 1]}, 0]}]}, 0]}, {'resprate_apache <= 13.5': [{'age <= 79.5': [{'map_apache <= 163.0': [{'apache_4a_icu_death_prob <= 0.615': [1, 0]}, 1]}, {'wbc_apache <= 11.649999999999999': [{'bun_apache <= 19.0': [0, 1]}, 0]}]}, {'wbc_apache <= 7.45': [0, {'bun_apache <= 14.5': [0, 1]}]}]}]}
# {'glucose_apache <= 160.5': [{'age <= 52.5': [{'sodium_apache <= 138.5': [{'creatinine_apache <= 5.01': [0, 1]}, 0]}, {'resprate_apache <= 15.5': [{'bun_apache <= 22.5': [{'sodium_apache <= 140.5': [0, 1]}, {'map_apache <= 120.0': [1, 0]}]}, {'weight <= 79.95': [0, {'glucose_apache <= 92.5': [1, 0]}]}]}]}, {'resprate_apache <= 28.5': [{'glucose_apache <= 191.0': [{'wbc_apache <= 8.9': [1, {'weight <= 117.25': [0, 1]}]}, {'sodium_apache <= 135.5': [{'wbc_apache <= 12.8': [0, 1]}, 1]}]}, {'weight <= 53.8': [0, {'map_apache <= 157.0': [1, {'map_apache <= 175.5': [0, 1]}]}]}]}]}
# {'glucose_apache <= 190.5': [{'age <= 51.5': [{'resprate_apache <= 31.5': [{'hematocrit_apache <= 22.45': [1, {'apache_4a_hospital_death_prob <= 0.09': [0, 1]}]}, 0]}, {'bmi <= 32.982294675': [{'map_apache <= 81.5': [{'glucose_apache <= 169.5': [0, 1]}, {'weight <= 95.9': [0, 1]}]}, {'wbc_apache <= 8.149999999999999': [1, {'weight <= 144.0': [0, 1]}]}]}]}, {'apache_4a_hospital_death_prob <= 0.39': [{'resprate_apache <= 48.5': [1, {'temp_apache <= 36.29': [0, {'hematocrit_apache <= 37.25': [0, 1]}]}]}, {'weight <= 115.55': [{'hematocrit_apache <= 27.25': [1, {'resprate_apache <= 14.5': [0, 1]}]}, 0]}]}]}
# {'weight <= 95.95': [{'resprate_apache <= 45.5': [{'creatinine_apache <= 1.5350000000000001': [{'creatinine_apache <= 0.67': [{'gcs_motor_apache <= 4.5': [0, 1]}, 0]}, 1]}, 0]}, {'map_apache <= 60.5': [{'weight <= 123.95': [{'gcs_verbal_apache <= 1.5': [1, {'sodium_apache <= 129.5': [0, 1]}]}, 1]}, {'temp_apache <= 36.95': [0, {'map_apache <= 138.5': [{'gcs_eyes_apache <= 2.5': [0, 1]}, 1]}]}]}]}
# {'resprate_apache <= 12.5': [{'height <= 175.23': [{'map_apache <= 140.0': [{'apache_4a_icu_death_prob <= 0.095': [{'apache_4a_icu_death_prob <= 0.055': [1, 0]}, 1]}, 1]}, {'hematocrit_apache <= 43.75': [{'resprate_apache <= 10.5': [{'wbc_apache <= 7.55': [0, 1]}, 1]}, 0]}]}, {'wbc_apache <= 3.1500000000000004': [0, {'map_apache <= 65.5': [{'gcs_verbal_apache <= 1.5': [1, {'wbc_apache <= 7.75': [0, 1]}]}, {'apache_4a_icu_death_prob <= 0.045': [0, {'map_apache <= 69.5': [0, 1]}]}]}]}]}
# {'glucose_apache <= 179.5': [{'hematocrit_apache <= 28.05': [{'heart_rate_apache <= 112.5': [{'gcs_verbal_apache <= 4.5': [1, {'hematocrit_apache <= 27.85': [0, 1]}]}, {'weight <= 80.05': [{'heart_rate_apache <= 151.0': [0, 1]}, {'glucose_apache <= 118.5': [0, 1]}]}]}, {'glucose_apache <= 82.5': [{'hematocrit_apache <= 28.85': [0, {'gcs_motor_apache <= 4.5': [0, 1]}]}, {'glucose_apache <= 149.5': [{'hematocrit_apache <= 28.450000000000003': [1, 0]}, 0]}]}]}, 1]}
# {'glucose_apache <= 172.5': [{'resprate_apache <= 17.5': [{'bun_apache <= 20.5': [0, {'glucose_apache <= 153.5': [{'glucose_apache <= 105.5': [1, 0]}, 1]}]}, {'temp_apache <= 36.150000000000006': [{'creatinine_apache <= 3.85': [0, 1]}, {'age <= 52.5': [0, {'glucose_apache <= 78.5': [1, 0]}]}]}]}, {'glucose_apache <= 260.5': [{'heart_rate_apache <= 112.0': [{'creatinine_apache <= 0.75': [1, {'bun_apache <= 9.5': [0, 1]}]}, {'map_apache <= 157.0': [{'temp_apache <= 35.0': [0, 1]}, 0]}]}, {'map_apache <= 62.5': [1, {'gcs_eyes_apache <= 3.5': [{'map_apache <= 66.5': [0, 1]}, {'heart_rate_apache <= 141.0': [1, 0]}]}]}]}]}
# {'glucose_apache <= 152.5': [0, {'resprate_apache <= 30.5': [{'glucose_apache <= 206.5': [{'wbc_apache <= 23.1': [1, 0]}, 1]}, {'glucose_apache <= 210.0': [{'bun_apache <= 89.5': [0, 1]}, 1]}]}]}
# {'glucose_apache <= 164.5': [{'map_apache <= 63.5': [{'heart_rate_apache <= 136.5': [{'glucose_apache <= 85.5': [{'bmi <= 18.09395122': [0, 1]}, {'heart_rate_apache <= 107.5': [1, 0]}]}, 0]}, {'sodium_apache <= 134.5': [0, {'glucose_apache <= 70.5': [1, 0]}]}]}, {'bmi <= 32.379614855': [{'apache_4a_icu_death_prob <= 0.37': [{'map_apache <= 57.5': [{'glucose_apache <= 383.0': [1, 0]}, {'glucose_apache <= 241.5': [0, 1]}]}, {'heart_rate_apache <= 119.5': [1, 0]}]}, 1]}]}
# {'resprate_apache <= 13.5': [{'bun_apache <= 15.5': [{'creatinine_apache <= 0.66': [{'height <= 168.8': [{'wbc_apache <= 9.100000000000001': [0, 1]}, 1]}, {'height <= 184.15': [{'temp_apache <= 36.849999999999994': [0, 1]}, 1]}]}, {'creatinine_apache <= 0.715': [1, {'gcs_eyes_apache <= 2.5': [{'heart_rate_apache <= 50.5': [0, 1]}, {'temp_apache <= 36.45': [1, 0]}]}]}]}, 0]}
# {'map_apache <= 60.5': [{'heart_rate_apache <= 117.5': [{'heart_rate_apache <= 50.5': [{'wbc_apache <= 7.95': [0, {'map_apache <= 45.5': [0, 1]}]}, {'sodium_apache <= 127.5': [0, 1]}]}, {'wbc_apache <= 22.85': [{'gcs_motor_apache <= 2.5': [1, 0]}, 0]}]}, {'wbc_apache <= 6.75': [0, {'creatinine_apache <= 0.42000000000000004': [1, {'temp_apache <= 36.05': [{'hematocrit_apache <= 40.45': [1, 0]}, {'map_apache <= 127.5': [0, 1]}]}]}]}]}
# {'glucose_apache <= 212.5': [0, 1]}
# {'resprate_apache <= 13.5': [{'resprate_apache <= 7.5': [{'age <= 46.0': [{'wbc_apache <= 5.1': [1, {'creatinine_apache <= 1.455': [0, 1]}]}, {'apache_4a_icu_death_prob <= 0.035': [{'creatinine_apache <= 1.04': [1, 0]}, 1]}]}, {'hematocrit_apache <= 37.5': [{'age <= 29.5': [0, 1]}, {'age <= 68.5': [{'sodium_apache <= 138.5': [1, 0]}, 1]}]}]}, {'creatinine_apache <= 1.23': [0, {'age <= 51.5': [{'height <= 184.15': [0, 1]}, {'wbc_apache <= 7.699999999999999': [{'creatinine_apache <= 3.31': [0, 1]}, 1]}]}]}]}
# {'bmi <= 27.446421200000003': [{'bun_apache <= 21.5': [{'bmi <= 19.32844692': [1, {'gcs_motor_apache <= 3.5': [{'heart_rate_apache <= 109.0': [0, 1]}, 0]}]}, {'wbc_apache <= 9.45': [0, {'apache_4a_hospital_death_prob <= 0.035': [1, {'heart_rate_apache <= 107.5': [1, 0]}]}]}]}, {'age <= 61.5': [{'resprate_apache <= 31.5': [{'bun_apache <= 27.0': [{'creatinine_apache <= 0.45999999999999996': [1, 0]}, {'age <= 31.0': [0, 1]}]}, {'resprate_apache <= 58.5': [0, 1]}]}, {'creatinine_apache <= 0.675': [{'bmi <= 27.946923525': [0, 1]}, {'heart_rate_apache <= 37.5': [0, {'bun_apache <= 9.5': [0, 1]}]}]}]}]}
# {'glucose_apache <= 168.5': [{'resprate_apache <= 30.5': [{'apache_4a_hospital_death_prob <= 0.025': [0, {'glucose_apache <= 71.5': [1, {'bmi <= 37.042101360000004': [0, 1]}]}]}, {'glucose_apache <= 71.5': [{'bmi <= 20.697313095': [0, 1]}, 0]}]}, {'resprate_apache <= 18.0': [{'glucose_apache <= 194.0': [{'glucose_apache <= 187.5': [1, 0]}, {'temp_apache <= 36.150000000000006': [{'bmi <= 41.126192605': [1, 0]}, 1]}]}, {'bmi <= 30.564255745': [0, {'wbc_apache <= 15.45': [{'resprate_apache <= 25.0': [0, 1]}, {'temp_apache <= 37.150000000000006': [0, 1]}]}]}]}]}
# {'glucose_apache <= 177.5': [{'glucose_apache <= 82.5': [{'age <= 56.5': [{'apache_4a_hospital_death_prob <= 0.08': [0, 1]}, {'weight <= 59.15': [0, {'resprate_apache <= 48.5': [1, 0]}]}]}, {'bmi <= 25.931299905': [0, {'age <= 59.5': [{'bmi <= 26.291084615000003': [1, 0]}, {'resprate_apache <= 15.5': [1, 0]}]}]}]}, {'apache_4a_hospital_death_prob <= 0.455': [{'resprate_apache <= 42.5': [{'glucose_apache <= 233.0': [{'glucose_apache <= 224.5': [1, 0]}, 1]}, {'glucose_apache <= 230.0': [0, {'resprate_apache <= 50.5': [1, 0]}]}]}, {'hematocrit_apache <= 33.7': [{'weight <= 112.7': [{'gcs_eyes_apache <= 2.5': [0, 1]}, 1]}, 0]}]}]}
# {'resprate_apache <= 32.5': [{'hematocrit_apache <= 42.05': [{'age <= 62.5': [{'sodium_apache <= 125.0': [0, {'sodium_apache <= 130.5': [1, 0]}]}, {'bmi <= 29.06468985': [{'wbc_apache <= 4.5': [0, 1]}, {'weight <= 165.8': [1, 0]}]}]}, {'resprate_apache <= 10.5': [0, {'bmi <= 26.030919245': [0, {'wbc_apache <= 14.55': [0, 1]}]}]}]}, {'bmi <= 60.80188049': [{'bmi <= 23.387224619999998': [{'hematocrit_apache <= 35.2': [{'gcs_verbal_apache <= 2.5': [1, 0]}, 0]}, {'bmi <= 48.125': [{'temp_apache <= 36.105000000000004': [1, 0]}, 0]}]}, 1]}]}
# {'resprate_apache <= 32.5': [{'bun_apache <= 21.5': [{'creatinine_apache <= 0.535': [1, {'age <= 58.5': [0, {'weight <= 77.555': [0, 1]}]}]}, {'weight <= 50.48': [0, {'wbc_apache <= 3.3': [0, 1]}]}]}, {'apache_4a_icu_death_prob <= 0.025': [{'creatinine_apache <= 0.805': [0, {'bun_apache <= 25.0': [0, {'sodium_apache <= 135.5': [1, 0]}]}]}, {'age <= 65.5': [{'resprate_apache <= 49.5': [{'sodium_apache <= 138.5': [0, 1]}, 0]}, {'apache_4a_icu_death_prob <= 0.635': [{'sodium_apache <= 136.5': [1, 0]}, 0]}]}]}]}
# {'age <= 53.5': [{'bun_apache <= 13.5': [{'map_apache <= 154.5': [{'temp_apache <= 39.099999999999994': [0, 1]}, 1]}, {'weight <= 54.6': [0, {'creatinine_apache <= 0.705': [1, 0]}]}]}, {'heart_rate_apache <= 121.5': [{'gcs_verbal_apache <= 1.5': [{'apache_4a_hospital_death_prob <= 0.07': [1, {'height <= 170.1': [1, 0]}]}, {'apache_4a_hospital_death_prob <= 0.005': [0, {'weight <= 67.95': [0, 1]}]}]}, {'creatinine_apache <= 1.87': [{'height <= 158.74': [1, {'weight <= 90.85': [0, 1]}]}, {'temp_apache <= 36.650000000000006': [{'creatinine_apache <= 3.135': [1, 0]}, 1]}]}]}]}
# {'glucose_apache <= 161.5': [{'heart_rate_apache <= 136.5': [{'apache_4a_icu_death_prob <= 0.015': [{'height <= 151.2': [1, {'creatinine_apache <= 0.44999999999999996': [1, 0]}]}, 0]}, 0]}, {'apache_4a_icu_death_prob <= 0.385': [{'glucose_apache <= 186.5': [{'gcs_motor_apache <= 5.5': [1, {'creatinine_apache <= 1.545': [0, 1]}]}, {'wbc_apache <= 4.65': [0, 1]}]}, {'wbc_apache <= 5.8': [1, {'bun_apache <= 39.5': [0, 1]}]}]}]}
# {'bmi <= 26.816681340000002': [{'apache_4a_icu_death_prob <= 0.035': [{'bun_apache <= 43.5': [0, 1]}, {'temp_apache <= 36.55': [{'height <= 152.7': [0, {'sodium_apache <= 138.5': [0, 1]}]}, {'sodium_apache <= 147.5': [0, 1]}]}]}, {'age <= 62.5': [{'bmi <= 27.53759198': [0, {'age <= 37.5': [0, {'weight <= 73.69999999999999': [0, 1]}]}]}, 1]}]}
# {'resprate_apache <= 35.5': [{'age <= 41.5': [{'creatinine_apache <= 0.555': [1, {'age <= 18.5': [1, {'bun_apache <= 33.5': [0, 1]}]}]}, {'weight <= 54.95': [{'creatinine_apache <= 0.505': [1, 0]}, {'hematocrit_apache <= 42.150000000000006': [1, {'sodium_apache <= 138.0': [1, 0]}]}]}]}, {'creatinine_apache <= 0.435': [1, {'creatinine_apache <= 1.82': [{'resprate_apache <= 45.5': [{'hematocrit_apache <= 25.75': [1, 0]}, 0]}, {'creatinine_apache <= 1.9': [1, {'apache_4a_hospital_death_prob <= 0.04': [0, 1]}]}]}]}]}
# {'glucose_apache <= 158.5': [{'creatinine_apache <= 1.21': [{'hematocrit_apache <= 41.75': [{'glucose_apache <= 68.5': [1, {'heart_rate_apache <= 45.0': [1, 0]}]}, 0]}, {'wbc_apache <= 17.6': [{'glucose_apache <= 80.5': [{'wbc_apache <= 5.1': [0, 1]}, 0]}, 0]}]}, {'glucose_apache <= 238.5': [{'heart_rate_apache <= 113.5': [1, {'bun_apache <= 72.5': [{'hematocrit_apache <= 21.200000000000003': [1, 0]}, 1]}]}, {'hematocrit_apache <= 46.25': [1, 0]}]}]}
# {'glucose_apache <= 172.5': [{'bmi <= 25.234540969999998': [{'heart_rate_apache <= 130.5': [{'glucose_apache <= 62.0': [1, {'bmi <= 15.10392993': [1, 0]}]}, 0]}, {'gcs_verbal_apache <= 1.5': [{'bmi <= 28.800175250000002': [1, {'weight <= 94.2': [0, 1]}]}, {'glucose_apache <= 149.5': [0, {'bmi <= 30.422853765': [0, 1]}]}]}]}, {'map_apache <= 135.5': [{'apache_4a_icu_death_prob <= 0.315': [{'glucose_apache <= 254.5': [{'heart_rate_apache <= 117.0': [1, 0]}, 1]}, {'map_apache <= 44.5': [1, 0]}]}, {'bun_apache <= 47.0': [{'bun_apache <= 41.0': [{'apache_4a_icu_death_prob <= 0.16999999999999998': [1, 0]}, 1]}, 0]}]}]}
# {'glucose_apache <= 186.5': [{'age <= 52.5': [{'hematocrit_apache <= 27.45': [{'hematocrit_apache <= 26.6': [{'sodium_apache <= 141.5': [0, 1]}, 1]}, {'heart_rate_apache <= 98.0': [{'sodium_apache <= 137.5': [1, 0]}, 0]}]}, {'glucose_apache <= 86.5': [{'weight <= 77.6': [{'age <= 73.0': [1, 0]}, {'age <= 56.5': [0, 1]}]}, {'glucose_apache <= 143.5': [0, {'weight <= 67.39': [0, 1]}]}]}]}, {'hematocrit_apache <= 39.35': [{'bun_apache <= 7.5': [0, {'bun_apache <= 99.5': [1, 0]}]}, {'weight <= 91.7': [{'age <= 59.0': [0, 1]}, {'weight <= 104.69999999999999': [0, {'heart_rate_apache <= 113.5': [0, 1]}]}]}]}]}
# {'bmi <= 26.63949043': [{'resprate_apache <= 31.5': [{'height <= 175.23': [{'bun_apache <= 13.5': [0, 1]}, {'temp_apache <= 36.25': [{'hematocrit_apache <= 34.0': [1, 0]}, {'resprate_apache <= 30.5': [0, 1]}]}]}, {'bun_apache <= 14.5': [0, {'bmi <= 18.98779372': [1, 0]}]}]}, {'hematocrit_apache <= 38.3': [1, {'resprate_apache <= 33.5': [{'apache_4a_hospital_death_prob <= 0.095': [{'apache_4a_hospital_death_prob <= 0.045': [0, 1]}, 0]}, {'hematocrit_apache <= 40.099999999999994': [0, {'temp_apache <= 36.425': [1, 0]}]}]}]}]}
# {'bmi <= 25.20768043': [{'hematocrit_apache <= 36.3': [{'creatinine_apache <= 0.55': [{'temp_apache <= 36.349999999999994': [0, 1]}, {'creatinine_apache <= 5.355': [0, 1]}]}, {'height <= 154.45': [1, {'wbc_apache <= 4.550000000000001': [1, {'apache_4a_hospital_death_prob <= 0.635': [0, 1]}]}]}]}, {'creatinine_apache <= 1.0350000000000001': [{'creatinine_apache <= 0.405': [1, 0]}, {'bmi <= 32.23089568': [{'bmi <= 25.41314555': [1, {'bmi <= 27.716525240000003': [0, 1]}]}, {'temp_apache <= 39.349999999999994': [1, 0]}]}]}]}
# {'glucose_apache <= 178.5': [0, {'intubated_apache <= 0': [{'sodium_apache <= 133.5': [{'map_apache <= 68.5': [{'glucose_apache <= 228.0': [0, 1]}, 0]}, 1]}, {'map_apache <= 57.5': [{'glucose_apache <= 187.0': [0, {'wbc_apache <= 3.8499999999999996': [0, 1]}]}, {'sodium_apache <= 136.5': [0, {'hematocrit_apache <= 32.95': [1, 0]}]}]}]}]}
# {'resprate_apache <= 30.5': [{'age <= 52.5': [{'hematocrit_apache <= 40.95': [{'temp_apache <= 36.650000000000006': [{'resprate_apache <= 6.5': [0, 1]}, {'hematocrit_apache <= 23.1': [1, 0]}]}, 0]}, 1]}, {'creatinine_apache <= 6.279999999999999': [{'temp_apache <= 36.150000000000006': [{'creatinine_apache <= 0.6399999999999999': [1, 0]}, {'gcs_eyes_apache <= 3.5': [{'apache_4a_hospital_death_prob <= 0.1': [1, 0]}, 0]}]}, {'age <= 41.0': [0, 1]}]}]}
# {'resprate_apache <= 37.5': [1, {'bun_apache <= 9.5': [{'resprate_apache <= 57.5': [0, 1]}, 0]}]}
# {'glucose_apache <= 169.5': [{'gcs_verbal_apache <= 1.5': [{'hematocrit_apache <= 30.35': [{'apache_4a_icu_death_prob <= 0.295': [{'sodium_apache <= 134.0': [0, 1]}, 0]}, {'weight <= 107.66': [0, 1]}]}, {'weight <= 68.02000000000001': [0, {'glucose_apache <= 61.5': [{'resprate_apache <= 40.5': [1, 0]}, 0]}]}]}, {'resprate_apache <= 34.5': [{'sodium_apache <= 141.5': [{'glucose_apache <= 221.5': [{'apache_4a_icu_death_prob <= 0.045': [1, 0]}, 1]}, 1]}, {'glucose_apache <= 264.0': [{'bun_apache <= 12.5': [0, {'weight <= 118.245': [0, 1]}]}, {'weight <= 140.57': [1, 0]}]}]}]}
# {'glucose_apache <= 164.5': [{'apache_4a_hospital_death_prob <= 0.055': [{'gcs_verbal_apache <= 1.5': [{'intubated_apache <= 0': [0, 1]}, {'map_apache <= 194.0': [{'height <= 151.2': [1, 0]}, 1]}]}, {'heart_rate_apache <= 97.5': [{'heart_rate_apache <= 57.5': [{'hematocrit_apache <= 36.3': [1, 0]}, 1]}, {'temp_apache <= 37.05': [{'apache_4a_hospital_death_prob <= 0.405': [0, 1]}, {'hematocrit_apache <= 41.95': [0, 1]}]}]}]}, {'map_apache <= 75.5': [{'heart_rate_apache <= 126.5': [{'wbc_apache <= 6.779999999999999': [{'heart_rate_apache <= 110.0': [0, 1]}, 1]}, {'height <= 166.35': [{'temp_apache <= 35.5': [0, 1]}, {'wbc_apache <= 8.265': [1, 0]}]}]}, {'wbc_apache <= 23.25': [{'glucose_apache <= 220.0': [{'map_apache <= 126.0': [0, 1]}, {'map_apache <= 173.0': [1, 0]}]}, {'map_apache <= 168.5': [0, 1]}]}]}]}
# {'bun_apache <= 20.5': [{'heart_rate_apache <= 51.5': [0, {'heart_rate_apache <= 115.5': [{'creatinine_apache <= 0.795': [1, {'creatinine_apache <= 1.755': [0, 1]}]}, {'weight <= 107.4': [0, {'height <= 170.3': [0, 1]}]}]}]}, {'heart_rate_apache <= 115.5': [{'creatinine_apache <= 9.25': [1, 0]}, {'creatinine_apache <= 5.395': [{'heart_rate_apache <= 116.5': [0, {'height <= 189.0': [0, 1]}]}, 1]}]}]}
# {'glucose_apache <= 195.5': [0, {'apache_4a_hospital_death_prob <= 0.125': [{'weight <= 58.75': [{'glucose_apache <= 273.5': [0, 1]}, 1]}, {'sodium_apache <= 126.5': [0, {'heart_rate_apache <= 136.5': [{'heart_rate_apache <= 122.5': [1, 0]}, 1]}]}]}]}
# {'glucose_apache <= 191.5': [{'age <= 44.5': [0, {'hematocrit_apache <= 38.849999999999994': [{'sodium_apache <= 137.5': [0, {'heart_rate_apache <= 143.0': [1, 0]}]}, {'height <= 162.57999999999998': [{'hematocrit_apache <= 45.25': [0, 1]}, 0]}]}]}, {'heart_rate_apache <= 123.5': [{'apache_4a_icu_death_prob <= 0.745': [1, 0]}, {'glucose_apache <= 215.5': [0, 1]}]}]}
# {'resprate_apache <= 11.5': [{'age <= 67.5': [{'apache_4a_hospital_death_prob <= 0.060000000000000005': [{'creatinine_apache <= 0.59': [1, {'sodium_apache <= 133.0': [1, 0]}]}, {'sodium_apache <= 135.5': [0, 1]}]}, {'bmi <= 28.70548368': [{'creatinine_apache <= 0.74': [1, {'temp_apache <= 36.3': [1, 0]}]}, {'apache_4a_hospital_death_prob <= 0.765': [1, 0]}]}]}, {'bun_apache <= 19.5': [{'bmi <= 20.656439355': [0, {'creatinine_apache <= 0.605': [{'resprate_apache <= 45.5': [1, 0]}, 0]}]}, {'bmi <= 26.676080255000002': [0, {'resprate_apache <= 42.5': [1, {'bmi <= 34.533637495': [0, 1]}]}]}]}]}
# {'creatinine_apache <= 1.6150000000000002': [{'map_apache <= 72.5': [{'wbc_apache <= 22.35': [{'creatinine_apache <= 0.63': [1, {'weight <= 71.25': [0, 1]}]}, {'weight <= 144.15': [{'map_apache <= 43.0': [1, 0]}, 1]}]}, {'gcs_eyes_apache <= 3.5': [{'age <= 36.0': [0, {'weight <= 104.55': [0, 1]}]}, {'weight <= 86.37': [0, {'age <= 69.5': [0, 1]}]}]}]}, {'age <= 80.5': [{'apache_4a_icu_death_prob <= 0.88': [1, 0]}, {'weight <= 43.099999999999994': [1, {'wbc_apache <= 10.25': [0, {'wbc_apache <= 21.9': [1, 0]}]}]}]}]}
# {'glucose_apache <= 164.5': [{'bun_apache <= 25.5': [{'weight <= 118.65': [0, {'heart_rate_apache <= 78.0': [0, 1]}]}, {'glucose_apache <= 86.5': [{'bun_apache <= 48.5': [1, {'wbc_apache <= 7.85': [0, 1]}]}, {'weight <= 106.9': [0, 1]}]}]}, {'temp_apache <= 39.650000000000006': [{'glucose_apache <= 186.5': [{'apache_4a_icu_death_prob <= 0.22999999999999998': [{'temp_apache <= 35.95': [0, 1]}, 1]}, {'heart_rate_apache <= 122.5': [{'apache_4a_icu_death_prob <= 0.45': [1, 0]}, {'glucose_apache <= 258.5': [0, 1]}]}]}, 0]}]}
# {'glucose_apache <= 171.5': [{'age <= 45.5': [0, {'bmi <= 25.18303176': [{'gcs_motor_apache <= 3.5': [1, {'bmi <= 15.318185725': [1, 0]}]}, {'glucose_apache <= 80.0': [1, 0]}]}]}, {'bmi <= 31.898953605000003': [{'creatinine_apache <= 0.695': [1, {'bmi <= 31.411960639999997': [{'gcs_motor_apache <= 3.5': [0, 1]}, 0]}]}, {'weight <= 152.15': [{'hematocrit_apache <= 47.900000000000006': [1, 0]}, 0]}]}]}
# {'bmi <= 32.348377479999996': [{'map_apache <= 80.0': [{'creatinine_apache <= 0.665': [{'map_apache <= 41.5': [0, 1]}, {'hematocrit_apache <= 25.95': [{'hematocrit_apache <= 23.15': [0, 1]}, 0]}]}, {'creatinine_apache <= 1.225': [{'apache_4a_icu_death_prob <= -0.5': [1, 0]}, {'creatinine_apache <= 1.295': [1, {'hematocrit_apache <= 37.8': [1, 0]}]}]}]}, {'bun_apache <= 83.5': [{'map_apache <= 109.5': [{'map_apache <= 59.5': [{'bun_apache <= 27.5': [0, 1]}, 1]}, {'hematocrit_apache <= 37.75': [1, {'hematocrit_apache <= 49.8': [0, 1]}]}]}, 0]}]}
# {'weight <= 79.815': [{'sodium_apache <= 141.5': [{'heart_rate_apache <= 120.5': [{'heart_rate_apache <= 52.5': [0, {'creatinine_apache <= 1.2349999999999999': [0, 1]}]}, 0]}, {'temp_apache <= 36.105000000000004': [{'weight <= 76.0': [1, 0]}, {'wbc_apache <= 10.05': [{'wbc_apache <= 5.45': [1, 0]}, {'hematocrit_apache <= 41.55': [1, 0]}]}]}]}, {'age <= 50.5': [{'temp_apache <= 36.849999999999994': [{'creatinine_apache <= 5.8100000000000005': [{'wbc_apache <= 38.6': [0, 1]}, 1]}, 1]}, {'temp_apache <= 36.150000000000006': [{'heart_rate_apache <= 54.5': [0, 1]}, 1]}]}]}
# {'glucose_apache <= 164.5': [{'gcs_verbal_apache <= 1.5': [{'hematocrit_apache <= 29.299999999999997': [{'sodium_apache <= 141.5': [{'creatinine_apache <= 4.885': [1, 0]}, 0]}, {'bun_apache <= 34.0': [{'apache_4a_icu_death_prob <= 0.025': [1, 0]}, 1]}]}, {'creatinine_apache <= 2.335': [0, {'glucose_apache <= 57.5': [1, {'creatinine_apache <= 3.09': [1, 0]}]}]}]}, {'glucose_apache <= 229.5': [{'creatinine_apache <= 0.47': [1, {'creatinine_apache <= 0.545': [0, 1]}]}, {'apache_4a_hospital_death_prob <= 0.10500000000000001': [{'bun_apache <= 52.0': [1, 0]}, {'glucose_apache <= 241.5': [1, {'wbc_apache <= 17.95': [0, 1]}]}]}]}]}
# {'glucose_apache <= 186.5': [{'resprate_apache <= 13.5': [{'age <= 48.5': [{'map_apache <= 127.0': [0, 1]}, {'glucose_apache <= 76.5': [1, {'glucose_apache <= 140.0': [0, 1]}]}]}, {'age <= 65.5': [0, {'creatinine_apache <= 7.64': [{'resprate_apache <= 57.5': [0, 1]}, 1]}]}]}, {'gcs_motor_apache <= 4.5': [{'bmi <= 28.471488605': [{'sodium_apache <= 141.5': [{'resprate_apache <= 13.0': [1, 0]}, 1]}, {'age <= 72.5': [1, 0]}]}, {'creatinine_apache <= 8.774999999999999': [{'resprate_apache <= 55.5': [1, 0]}, 0]}]}]}
# {'bmi <= 24.484391979999998': [{'weight <= 75.035': [{'creatinine_apache <= 0.505': [{'heart_rate_apache <= 109.5': [0, 1]}, {'heart_rate_apache <= 138.5': [{'hematocrit_apache <= 25.55': [1, 0]}, 0]}]}, 0]}, {'hematocrit_apache <= 27.95': [{'heart_rate_apache <= 101.5': [{'heart_rate_apache <= 51.0': [0, {'bmi <= 48.153165560000005': [1, 0]}]}, {'temp_apache <= 35.849999999999994': [1, {'sodium_apache <= 131.0': [1, 0]}]}]}, {'sodium_apache <= 141.5': [{'creatinine_apache <= 0.749': [{'hematocrit_apache <= 34.25': [0, 1]}, 0]}, 0]}]}]}
# {'bmi <= 35.34431844': [{'age <= 61.5': [{'creatinine_apache <= 1.27': [{'wbc_apache <= 5.800000000000001': [0, {'creatinine_apache <= 0.565': [1, 0]}]}, {'age <= 56.5': [{'wbc_apache <= 22.55': [1, 0]}, {'temp_apache <= 36.75': [0, 1]}]}]}, {'gcs_motor_apache <= 5.5': [{'apache_4a_icu_death_prob <= 0.25': [1, {'age <= 78.5': [1, 0]}]}, {'height <= 164.75': [0, {'hematocrit_apache <= 25.95': [1, 0]}]}]}]}, {'age <= 39.5': [0, {'bmi <= 35.96967093': [1, {'hematocrit_apache <= 39.400000000000006': [{'bmi <= 48.34495722': [1, 0]}, {'gcs_eyes_apache <= 3.5': [1, 0]}]}]}]}]}
# {'glucose_apache <= 187.5': [{'bun_apache <= 17.5': [{'creatinine_apache <= 0.675': [{'temp_apache <= 36.05': [1, {'glucose_apache <= 169.5': [0, 1]}]}, {'creatinine_apache <= 0.865': [0, {'glucose_apache <= 63.0': [1, 0]}]}]}, {'wbc_apache <= 2.45': [0, {'bun_apache <= 88.0': [{'map_apache <= 193.5': [0, 1]}, 0]}]}]}, {'apache_4a_hospital_death_prob <= 0.415': [{'glucose_apache <= 208.5': [{'wbc_apache <= 6.949999999999999': [1, {'creatinine_apache <= 0.73': [1, 0]}]}, {'map_apache <= 52.5': [1, {'creatinine_apache <= 11.09': [1, 0]}]}]}, {'glucose_apache <= 253.5': [{'map_apache <= 164.0': [0, 1]}, {'bun_apache <= 74.5': [{'map_apache <= 147.0': [1, 0]}, 1]}]}]}]}
# {'glucose_apache <= 161.5': [{'glucose_apache <= 86.5': [{'weight <= 55.3': [0, {'map_apache <= 52.5': [{'resprate_apache <= 9.0': [0, 1]}, {'resprate_apache <= 38.5': [1, 0]}]}]}, {'weight <= 123.8': [0, {'heart_rate_apache <= 52.5': [0, 1]}]}]}, {'glucose_apache <= 250.0': [{'resprate_apache <= 33.5': [{'glucose_apache <= 192.0': [{'glucose_apache <= 182.0': [1, 0]}, 1]}, {'weight <= 147.0': [{'heart_rate_apache <= 154.5': [0, 1]}, 1]}]}, {'heart_rate_apache <= 105.0': [1, {'heart_rate_apache <= 106.5': [0, 1]}]}]}]}
# {'glucose_apache <= 173.5': [{'age <= 67.5': [{'apache_4a_hospital_death_prob <= 0.11499999999999999': [{'bmi <= 24.97630886': [{'heart_rate_apache <= 145.5': [0, 1]}, 0]}, {'bmi <= 34.71748539': [0, {'heart_rate_apache <= 126.0': [1, 0]}]}]}, {'glucose_apache <= 80.5': [1, 0]}]}, {'glucose_apache <= 222.5': [{'heart_rate_apache <= 109.5': [{'height <= 172.35': [1, {'heart_rate_apache <= 100.5': [0, 1]}]}, {'height <= 182.95': [{'bmi <= 27.71139713': [0, 1]}, 1]}]}, {'bmi <= 36.21363318': [{'glucose_apache <= 238.5': [1, {'bmi <= 17.139747885': [0, 1]}]}, 1]}]}]}
# {'resprate_apache <= 13.5': [{'heart_rate_apache <= 90.5': [{'height <= 180.32': [{'sodium_apache <= 132.5': [1, {'sodium_apache <= 136.5': [0, 1]}]}, 0]}, {'map_apache <= 60.5': [{'hematocrit_apache <= 33.25': [{'heart_rate_apache <= 115.5': [1, 0]}, 1]}, {'hematocrit_apache <= 18.85': [0, {'height <= 172.45': [1, 0]}]}]}]}, {'bmi <= 24.048051875': [{'height <= 176.55': [0, {'hematocrit_apache <= 31.15': [0, {'hematocrit_apache <= 42.8': [1, 0]}]}]}, {'gcs_verbal_apache <= 2.5': [{'gcs_motor_apache <= 4.5': [{'resprate_apache <= 48.5': [1, 0]}, {'resprate_apache <= 19.5': [0, 1]}]}, {'resprate_apache <= 39.5': [{'apache_4a_hospital_death_prob <= 0.07500000000000001': [0, 1]}, {'heart_rate_apache <= 58.5': [1, 0]}]}]}]}]}
# {'resprate_apache <= 36.5': [{'apache_4a_hospital_death_prob <= 0.545': [{'resprate_apache <= 14.5': [{'height <= 175.28': [1, {'hematocrit_apache <= 38.5': [1, 0]}]}, {'bmi <= 31.816001485': [{'temp_apache <= 35.95': [1, 0]}, {'bmi <= 54.827332495': [1, 0]}]}]}, 1]}, {'bmi <= 32.58137976': [{'map_apache <= 41.5': [1, {'creatinine_apache <= 0.445': [1, 0]}]}, {'hematocrit_apache <= 43.900000000000006': [{'bmi <= 33.831402825': [1, {'resprate_apache <= 53.5': [1, 0]}]}, 0]}]}]}
# {'resprate_apache <= 29.5': [{'age <= 39.5': [{'resprate_apache <= 22.0': [0, 1]}, {'bun_apache <= 22.5': [{'creatinine_apache <= 0.635': [1, {'wbc_apache <= 5.300000000000001': [0, 1]}]}, 1]}]}, {'wbc_apache <= 10.25': [{'age <= 62.5': [{'resprate_apache <= 35.5': [0, {'bun_apache <= 100.0': [0, 1]}]}, {'apache_4a_hospital_death_prob <= 0.125': [{'sodium_apache <= 133.5': [1, 0]}, {'weight <= 78.65': [1, 0]}]}]}, {'creatinine_apache <= 2.76': [{'creatinine_apache <= 0.595': [1, {'apache_4a_hospital_death_prob <= 0.74': [0, 1]}]}, 1]}]}]}
# {'resprate_apache <= 34.5': [{'age <= 61.5': [{'map_apache <= 44.0': [0, {'resprate_apache <= 8.5': [{'age <= 39.0': [0, 1]}, 0]}]}, {'weight <= 95.6': [{'gcs_verbal_apache <= 1.5': [{'temp_apache <= 35.75': [0, 1]}, {'wbc_apache <= 8.350000000000001': [0, 1]}]}, {'age <= 83.5': [{'creatinine_apache <= 6.295': [1, 0]}, 0]}]}]}, {'weight <= 90.805': [0, {'age <= 38.0': [0, {'gcs_verbal_apache <= 1.5': [1, {'map_apache <= 42.5': [1, 0]}]}]}]}]}
# {'glucose_apache <= 164.5': [{'glucose_apache <= 78.5': [{'wbc_apache <= 6.95': [0, {'wbc_apache <= 9.05': [1, {'weight <= 100.35': [0, 1]}]}]}, {'weight <= 93.445': [0, {'glucose_apache <= 150.5': [0, 1]}]}]}, {'glucose_apache <= 204.5': [{'apache_4a_icu_death_prob <= 0.10500000000000001': [{'weight <= 84.19999999999999': [{'heart_rate_apache <= 122.0': [1, 0]}, 1]}, {'weight <= 90.25': [1, 0]}]}, {'apache_4a_icu_death_prob <= 0.055': [{'glucose_apache <= 574.85': [{'wbc_apache <= 27.25': [1, 0]}, 0]}, {'heart_rate_apache <= 145.0': [{'wbc_apache <= 19.450000000000003': [1, 0]}, 1]}]}]}]}
# {'glucose_apache <= 157.5': [{'age <= 45.5': [0, {'temp_apache <= 36.25': [{'resprate_apache <= 8.5': [1, {'height <= 156.2': [1, 0]}]}, {'bmi <= 33.203586965': [{'gcs_motor_apache <= 2.5': [1, 0]}, 0]}]}]}, {'glucose_apache <= 227.5': [{'resprate_apache <= 26.5': [{'apache_4a_icu_death_prob <= 0.2': [1, 0]}, {'age <= 62.0': [{'map_apache <= 181.0': [0, 1]}, {'temp_apache <= 36.45': [0, 1]}]}]}, {'map_apache <= 147.0': [{'resprate_apache <= 9.5': [1, {'height <= 152.2': [0, 1]}]}, {'age <= 59.0': [0, 1]}]}]}]}
# {'resprate_apache <= 34.5': [{'bun_apache <= 11.5': [{'age <= 34.5': [0, {'bmi <= 29.386391484999997': [0, {'map_apache <= 110.0': [1, 0]}]}]}, {'hematocrit_apache <= 42.150000000000006': [{'bmi <= 25.91586856': [{'heart_rate_apache <= 133.0': [1, 0]}, {'bun_apache <= 106.5': [1, 0]}]}, {'wbc_apache <= 9.75': [0, 1]}]}]}, {'bmi <= 33.91994442': [{'height <= 162.53': [{'bmi <= 30.989176285': [{'age <= 77.5': [0, 1]}, 0]}, 0]}, {'height <= 154.95': [0, {'bun_apache <= 13.0': [1, {'sodium_apache <= 138.5': [1, 0]}]}]}]}]}
# {'resprate_apache <= 32.5': [{'weight <= 83.95': [{'height <= 162.25': [{'height <= 151.55': [0, {'bun_apache <= 46.5': [1, 0]}]}, {'resprate_apache <= 11.5': [{'age <= 68.5': [1, 0]}, 0]}]}, {'resprate_apache <= 4.5': [0, {'age <= 84.5': [1, 0]}]}]}, {'age <= 61.5': [{'resprate_apache <= 41.5': [{'weight <= 99.15': [{'bun_apache <= 41.0': [0, 1]}, {'map_apache <= 61.5': [1, 0]}]}, {'weight <= 165.15': [0, 1]}]}, {'height <= 177.4': [{'gcs_verbal_apache <= 1.5': [1, {'bun_apache <= 76.5': [0, 1]}]}, {'weight <= 129.8': [0, 1]}]}]}]}
# {'glucose_apache <= 164.5': [{'hematocrit_apache <= 39.1': [{'age <= 56.5': [{'hematocrit_apache <= 24.35': [{'gcs_eyes_apache <= 3.5': [1, 0]}, 0]}, {'glucose_apache <= 70.5': [1, {'gcs_verbal_apache <= 1.5': [1, 0]}]}]}, {'glucose_apache <= 92.0': [{'glucose_apache <= 88.0': [0, 1]}, 0]}]}, {'hematocrit_apache <= 32.4': [{'heart_rate_apache <= 151.5': [{'glucose_apache <= 199.5': [{'hematocrit_apache <= 27.45': [1, 0]}, 1]}, 0]}, {'gcs_eyes_apache <= 1.5': [{'bun_apache <= 40.5': [0, 1]}, {'creatinine_apache <= 1.365': [1, {'height <= 184.15': [0, 1]}]}]}]}]}
# {'age <= 44.5': [{'map_apache <= 109.5': [{'temp_apache <= 35.55': [1, {'creatinine_apache <= 0.6799999999999999': [1, 0]}]}, {'creatinine_apache <= 0.575': [1, 0]}]}, {'creatinine_apache <= 1.2149999999999999': [{'weight <= 88.5': [{'age <= 72.5': [{'map_apache <= 184.5': [0, 1]}, {'map_apache <= 48.5': [1, 0]}]}, {'sodium_apache <= 133.5': [0, 1]}]}, {'temp_apache <= 34.55': [{'map_apache <= 131.5': [0, 1]}, {'sodium_apache <= 143.5': [1, {'heart_rate_apache <= 61.0': [1, 0]}]}]}]}]}
# {'glucose_apache <= 196.5': [{'map_apache <= 57.5': [{'heart_rate_apache <= 113.5': [{'apache_4a_hospital_death_prob <= 0.035': [{'glucose_apache <= 135.0': [0, 1]}, {'weight <= 67.945': [0, 1]}]}, {'weight <= 73.41': [0, {'weight <= 89.6': [1, 0]}]}]}, {'temp_apache <= 36.21': [{'bun_apache <= 24.5': [{'glucose_apache <= 89.5': [1, 0]}, {'map_apache <= 66.0': [1, 0]}]}, {'weight <= 83.69999999999999': [0, {'glucose_apache <= 83.0': [1, 0]}]}]}]}, {'gcs_motor_apache <= 4.5': [{'weight <= 106.2': [{'heart_rate_apache <= 59.0': [1, 0]}, 1]}, {'map_apache <= 122.5': [1, {'heart_rate_apache <= 75.0': [1, {'temp_apache <= 36.349999999999994': [1, 0]}]}]}]}]}
# {'glucose_apache <= 161.5': [{'temp_apache <= 36.150000000000006': [{'sodium_apache <= 147.5': [{'glucose_apache <= 138.5': [{'glucose_apache <= 93.0': [1, 0]}, 1]}, 0]}, {'apache_4a_hospital_death_prob <= 0.055': [{'glucose_apache <= 80.5': [{'bmi <= 31.472766335': [0, 1]}, 0]}, {'heart_rate_apache <= 100.5': [1, {'glucose_apache <= 142.0': [0, 1]}]}]}]}, {'glucose_apache <= 245.5': [{'bmi <= 21.9820025': [{'height <= 166.35': [0, {'apache_4a_icu_death_prob <= 0.135': [1, 0]}]}, {'heart_rate_apache <= 122.5': [1, {'height <= 157.45': [1, 0]}]}]}, {'temp_apache <= 39.55': [1, 0]}]}]}
# {'bun_apache <= 13.5': [{'creatinine_apache <= 0.615': [{'wbc_apache <= 16.5': [{'height <= 176.53': [{'creatinine_apache <= 0.505': [1, 0]}, 1]}, 1]}, {'wbc_apache <= 14.75': [{'weight <= 119.2': [0, {'wbc_apache <= 7.25': [0, 1]}]}, 0]}]}, {'sodium_apache <= 134.5': [{'sodium_apache <= 123.5': [0, {'sodium_apache <= 124.5': [1, 0]}]}, {'weight <= 49.25': [0, {'bun_apache <= 96.0': [{'height <= 182.85000000000002': [1, 0]}, 0]}]}]}]}
# {'glucose_apache <= 164.5': [{'resprate_apache <= 13.5': [{'bmi <= 31.14654309': [{'weight <= 56.0': [1, 0]}, {'age <= 66.5': [0, 1]}]}, {'age <= 48.5': [0, {'bmi <= 25.024654060000003': [{'age <= 50.5': [1, 0]}, 0]}]}]}, {'glucose_apache <= 230.5': [{'resprate_apache <= 29.5': [1, {'temp_apache <= 36.92': [{'bmi <= 32.595013205': [0, 1]}, {'apache_4a_hospital_death_prob <= 0.035': [1, 0]}]}]}, {'glucose_apache <= 353.5': [{'resprate_apache <= 54.5': [1, 0]}, 1]}]}]}
# {'bmi <= 25.154429785': [{'resprate_apache <= 33.5': [0, {'bun_apache <= 11.5': [0, {'weight <= 71.45': [{'bun_apache <= 13.0': [1, 0]}, 0]}]}]}, {'resprate_apache <= 32.5': [{'bmi <= 47.271497960000005': [{'temp_apache <= 36.650000000000006': [{'hematocrit_apache <= 37.650000000000006': [1, 0]}, {'bmi <= 26.64646113': [0, 1]}]}, 1]}, {'hematocrit_apache <= 31.85': [{'creatinine_apache <= 0.585': [0, 1]}, {'height <= 170.14999999999998': [{'bun_apache <= 14.0': [0, 1]}, 0]}]}]}]}
# {'bun_apache <= 19.5': [{'resprate_apache <= 37.5': [{'hematocrit_apache <= 42.7': [{'heart_rate_apache <= 55.0': [{'resprate_apache <= 6.5': [1, 0]}, {'hematocrit_apache <= 41.55': [0, 1]}]}, {'hematocrit_apache <= 47.0': [0, 1]}]}, {'age <= 72.5': [0, {'apache_4a_hospital_death_prob <= 0.14500000000000002': [{'bun_apache <= 17.0': [0, 1]}, 0]}]}]}, {'height <= 180.15': [{'height <= 179.55': [{'height <= 175.1': [{'resprate_apache <= 33.5': [1, 0]}, 0]}, 1]}, {'resprate_apache <= 9.5': [{'bun_apache <= 25.0': [0, 1]}, 0]}]}]}
# {'glucose_apache <= 178.5': [{'age <= 41.0': [0, {'glucose_apache <= 71.5': [{'gcs_verbal_apache <= 4.5': [{'heart_rate_apache <= 132.0': [1, 0]}, {'age <= 77.0': [1, 0]}]}, {'glucose_apache <= 152.5': [0, {'height <= 153.65': [1, 0]}]}]}]}, {'heart_rate_apache <= 124.5': [{'map_apache <= 145.5': [1, {'heart_rate_apache <= 98.5': [{'heart_rate_apache <= 59.0': [0, 1]}, 0]}]}, {'glucose_apache <= 250.5': [{'map_apache <= 47.0': [0, {'bun_apache <= 9.5': [1, 0]}]}, {'glucose_apache <= 481.5': [1, 0]}]}]}]}
# {'glucose_apache <= 184.5': [{'glucose_apache <= 74.5': [{'temp_apache <= 38.4': [{'weight <= 63.0': [1, {'apache_4a_icu_death_prob <= 0.21000000000000002': [1, 0]}]}, 0]}, {'resprate_apache <= 35.5': [{'apache_4a_icu_death_prob <= 0.015': [0, {'glucose_apache <= 155.5': [0, 1]}]}, 0]}]}, {'temp_apache <= 34.150000000000006': [0, {'hematocrit_apache <= 19.9': [0, 1]}]}]}
# {'glucose_apache <= 165.0': [{'age <= 53.5': [{'resprate_apache <= 34.5': [{'creatinine_apache <= 0.62': [1, 0]}, 0]}, {'hematocrit_apache <= 31.95': [{'glucose_apache <= 96.5': [1, 0]}, {'resprate_apache <= 11.5': [0, {'creatinine_apache <= 0.5449999999999999': [1, 0]}]}]}]}, {'resprate_apache <= 15.0': [{'creatinine_apache <= 0.805': [1, {'resprate_apache <= 4.5': [0, 1]}]}, {'glucose_apache <= 346.5': [{'weight <= 63.849999999999994': [{'bun_apache <= 25.0': [0, 1]}, 1]}, {'weight <= 51.15': [0, 1]}]}]}]}
# {'glucose_apache <= 212.5': [{'glucose_apache <= 75.5': [{'resprate_apache <= 41.5': [{'bmi <= 37.385932145': [1, 0]}, 0]}, {'glucose_apache <= 165.5': [0, {'resprate_apache <= 32.0': [{'glucose_apache <= 187.5': [1, 0]}, 0]}]}]}, {'heart_rate_apache <= 135.5': [{'glucose_apache <= 587.85': [1, 0]}, {'map_apache <= 51.0': [0, {'bmi <= 28.800586420000002': [0, {'hematocrit_apache <= 21.35': [0, 1]}]}]}]}]}
# {'glucose_apache <= 195.0': [{'map_apache <= 57.5': [{'weight <= 77.15': [{'temp_apache <= 35.650000000000006': [1, 0]}, {'hematocrit_apache <= 28.2': [1, {'glucose_apache <= 142.5': [0, 1]}]}]}, {'glucose_apache <= 90.5': [{'age <= 44.5': [0, {'weight <= 58.95': [0, 1]}]}, 0]}]}, {'map_apache <= 126.5': [{'glucose_apache <= 305.0': [{'apache_4a_icu_death_prob <= 0.155': [1, {'map_apache <= 67.0': [1, 0]}]}, {'resprate_apache <= 5.5': [0, 1]}]}, {'hematocrit_apache <= 45.75': [1, 0]}]}]}
# {'glucose_apache <= 169.5': [{'gcs_verbal_apache <= 1.5': [{'temp_apache <= 34.57': [0, {'wbc_apache <= 8.75': [0, {'apache_4a_icu_death_prob <= 0.45999999999999996': [1, 0]}]}]}, 0]}, {'bmi <= 30.95694244': [{'glucose_apache <= 264.5': [{'map_apache <= 120.5': [1, {'wbc_apache <= 19.1': [0, 1]}]}, 1]}, {'glucose_apache <= 209.5': [{'sodium_apache <= 131.5': [0, {'sodium_apache <= 149.5': [1, 0]}]}, 1]}]}]}
# {'glucose_apache <= 167.5': [{'hematocrit_apache <= 31.6': [{'gcs_verbal_apache <= 1.5': [{'sodium_apache <= 134.5': [0, {'glucose_apache <= 64.0': [0, 1]}]}, {'bun_apache <= 36.5': [0, 1]}]}, {'gcs_eyes_apache <= 3.5': [{'height <= 147.45': [1, {'apache_4a_hospital_death_prob <= 0.685': [0, 1]}]}, {'glucose_apache <= 68.5': [1, 0]}]}]}, {'glucose_apache <= 256.5': [{'apache_4a_hospital_death_prob <= 0.345': [{'apache_4a_hospital_death_prob <= -0.5': [0, 1]}, {'hematocrit_apache <= 33.0': [1, 0]}]}, {'apache_4a_hospital_death_prob <= 0.015': [1, {'heart_rate_apache <= 90.5': [1, {'heart_rate_apache <= 92.5': [0, 1]}]}]}]}]}
# {'glucose_apache <= 161.5': [{'bmi <= 27.26582142': [{'creatinine_apache <= 1.49': [{'sodium_apache <= 145.5': [0, 1]}, {'glucose_apache <= 103.0': [{'gcs_eyes_apache <= 3.5': [0, 1]}, {'hematocrit_apache <= 36.9': [0, 1]}]}]}, {'glucose_apache <= 95.5': [{'apache_4a_icu_death_prob <= 0.095': [{'creatinine_apache <= 1.1150000000000002': [0, 1]}, {'hematocrit_apache <= 34.75': [0, 1]}]}, {'height <= 185.2': [{'height <= 182.95': [0, 1]}, 0]}]}]}, {'glucose_apache <= 187.5': [{'hematocrit_apache <= 32.349999999999994': [{'height <= 174.01': [{'creatinine_apache <= 2.27': [1, 0]}, 1]}, {'apache_4a_icu_death_prob <= 0.045': [{'height <= 162.8': [0, 1]}, {'sodium_apache <= 130.5': [1, 0]}]}]}, 1]}]}
# ...
#  {'resprate_apache <= 41.5': [{'height <= 175.28': [{'weight <= 86.35': [{'sodium_apache <= 130.5': [1,
#          {'apache_4a_icu_death_prob <= 0.035': [0, 1]}]},
#        1]},
#      {'sodium_apache <= 131.5': [{'sodium_apache <= 123.5': [0, 1]},
#        {'temp_apache <= 36.150000000000006': [{'resprate_apache <= 33.5': [0,
#            1]},
#          0]}]}]},
#    {'sodium_apache <= 140.5': [{'heart_rate_apache <= 154.5': [0, 1]}, 0]}]},
#  {'bmi <= 27.528199835': [{'bmi <= 19.5137079': [0,
#      {'resprate_apache <= 13.5': [{'hematocrit_apache <= 30.1': [1,
#          {'bmi <= 26.36842275': [0, 1]}]},
#        0]}]},
#    {'resprate_apache <= 14.5': [{'map_apache <= 106.0': [1,
#        {'hematocrit_apache <= 28.450000000000003': [1,
#          {'map_apache <= 123.0': [0, 1]}]}]},
#      {'resprate_apache <= 21.0': [0,
#        {'resprate_apache <= 34.5': [{'wbc_apache <= 5.35': [0, 1]},
#          {'temp_apache <= 36.105000000000004': [1, 0]}]}]}]}]},
#  {'glucose_apache <= 168.0': [{'hematocrit_apache <= 37.650000000000006': [{'resprate_apache <= 31.5': [{'glucose_apache <= 69.5': [{'wbc_apache <= 19.700000000000003': [1,
#            0]},
#          {'sodium_apache <= 143.5': [0, 1]}]},
#        {'glucose_apache <= 90.5': [{'wbc_apache <= 8.7': [0, 1]},
#          {'weight <= 107.8': [0, 1]}]}]},
#      {'creatinine_apache <= 0.59': [1, 0]}]},
#    {'resprate_apache <= 32.5': [{'glucose_apache <= 201.5': [{'sodium_apache <= 133.5': [0,
#          1]},
#        {'sodium_apache <= 156.0': [1, 0]}]},
#      {'glucose_apache <= 262.5': [{'weight <= 80.94999999999999': [0,
#          {'hematocrit_apache <= 41.55': [1, 0]}]},
#        1]}]}]},
#  {'glucose_apache <= 170.5': [0,
#    {'resprate_apache <= 35.5': [{'glucose_apache <= 211.5': [{'bun_apache <= 7.5': [0,
#          1]},
#        1]},
#      {'glucose_apache <= 437.5': [{'hematocrit_apache <= 28.6': [{'glucose_apache <= 205.5': [0,
#            1]},
#          0]},
#        1]}]}]},
#  {'glucose_apache <= 164.5': [{'resprate_apache <= 15.5': [{'creatinine_apache <= 0.55': [1,
#        {'gcs_verbal_apache <= 3.5': [{'gcs_eyes_apache <= 1.5': [0, 1]},
#          {'weight <= 72.63499999999999': [0, 1]}]}]},
#      {'glucose_apache <= 82.5': [{'wbc_apache <= 8.149999999999999': [0,
#          {'bmi <= 23.656541915': [0, 1]}]},
#        {'weight <= 66.8': [{'apache_4a_hospital_death_prob <= 0.32999999999999996': [0,
#            1]},
#          0]}]}]},
#    {'hematocrit_apache <= 47.75': [{'apache_4a_hospital_death_prob <= 0.33': [1,
#        {'apache_4a_hospital_death_prob <= 0.37': [0, 1]}]},
#      0]}]},
#  {'glucose_apache <= 197.5': [{'age <= 40.0': [0,
#      {'gcs_verbal_apache <= 3.5': [{'apache_4a_icu_death_prob <= 0.055': [1,
#          {'wbc_apache <= 11.8': [0, 1]}]},
#        {'creatinine_apache <= 0.535': [1,
#          {'glucose_apache <= 82.5': [1, 0]}]}]}]},
#    {'glucose_apache <= 233.5': [{'age <= 36.0': [0,
#        {'wbc_apache <= 5.35': [1, {'wbc_apache <= 20.8': [1, 0]}]}]},
#      {'bun_apache <= 84.5': [{'creatinine_apache <= 2.325': [1,
#          {'heart_rate_apache <= 140.5': [1, 0]}]},
#        0]}]}]},
#  {'glucose_apache <= 167.5': [0,
#    {'sodium_apache <= 137.5': [{'weight <= 93.5': [{'temp_apache <= 35.95': [{'sodium_apache <= 131.5': [1,
#            0]},
#          1]},
#        {'glucose_apache <= 305.5': [{'heart_rate_apache <= 115.0': [1, 0]},
#          1]}]},
#      {'glucose_apache <= 220.0': [{'apache_4a_hospital_death_prob <= 0.32999999999999996': [1,
#          0]},
#        {'apache_4a_hospital_death_prob <= 0.125': [{'gcs_eyes_apache <= 1.5': [0,
#            1]},
#          1]}]}]}]},
#  {'weight <= 99.9': [{'map_apache <= 72.5': [{'height <= 175.28': [{'weight <= 62.650000000000006': [0,
#          1]},
#        0]},
#      {'hematocrit_apache <= 37.0': [0,
#        {'height <= 167.62': [0, {'height <= 170.14999999999998': [1, 0]}]}]}]},
#    {'age <= 56.5': [{'apache_4a_icu_death_prob <= 0.025': [{'weight <= 142.15': [{'weight <= 132.6': [0,
#            1]},
#          0]},
#        {'map_apache <= 51.5': [0, 1]}]},
#      {'weight <= 104.9': [{'heart_rate_apache <= 138.0': [1, 0]}, 1]}]}]},
#  {'glucose_apache <= 171.5': [{'age <= 70.5': [{'bmi <= 34.70270919': [0,
#        {'hematocrit_apache <= 33.2': [{'apache_4a_hospital_death_prob <= 0.075': [0,
#            1]},
#          0]}]},
#      {'age <= 76.5': [{'creatinine_apache <= 1.025': [1,
#          {'glucose_apache <= 82.0': [1, 0]}]},
#        0]}]},
#    {'glucose_apache <= 232.5': [{'resprate_apache <= 31.5': [1,
#        {'bmi <= 25.682400004999998': [0,
#          {'hematocrit_apache <= 33.900000000000006': [1, 0]}]}]},
#      {'creatinine_apache <= 5.154999999999999': [{'heart_rate_apache <= 159.5': [1,
#          0]},
#        {'apache_4a_icu_death_prob <= 0.055': [0, 1]}]}]}]},
#  {'glucose_apache <= 197.5': [{'age <= 54.5': [{'resprate_apache <= 29.5': [{'hematocrit_apache <= 30.95': [{'sodium_apache <= 135.5': [0,
#            1]},
#          0]},
#        0]},
#      {'resprate_apache <= 35.5': [0,
#        {'heart_rate_apache <= 76.5': [{'apache_4a_hospital_death_prob <= 0.14500000000000002': [0,
#            1]},
#          {'glucose_apache <= 55.0': [1, 0]}]}]}]},
#    {'bun_apache <= 24.5': [{'resprate_apache <= 35.5': [{'gcs_motor_apache <= 4.5': [{'heart_rate_apache <= 125.5': [1,
#            0]},
#          1]},
#        {'glucose_apache <= 278.5': [{'hematocrit_apache <= 44.599999999999994': [0,
#            1]},
#          1]}]},
#      {'sodium_apache <= 123.5': [0, {'age <= 25.5': [0, 1]}]}]}]},
#  {'resprate_apache <= 15.5': [{'age <= 60.5': [{'bun_apache <= 31.0': [{'heart_rate_apache <= 125.5': [0,
#          1]},
#        1]},
#      {'height <= 175.23': [{'weight <= 46.6': [0, 1]},
#        {'hematocrit_apache <= 35.55': [{'weight <= 69.0': [0, 1]},
#          {'age <= 63.5': [1, 0]}]}]}]},
#    {'age <= 38.5': [{'bun_apache <= 6.5': [1, 0]},
#      {'weight <= 124.6': [0,
#        {'height <= 182.85000000000002': [{'bun_apache <= 46.5': [1, 0]},
#          {'hematocrit_apache <= 42.599999999999994': [0, 1]}]}]}]}]},
#  {'resprate_apache <= 35.5': [{'bun_apache <= 21.5': [{'map_apache <= 64.5': [{'height <= 162.25': [1,
#          {'temp_apache <= 37.25': [0, 1]}]},
#        {'map_apache <= 68.5': [{'resprate_apache <= 5.5': [1, 0]},
#          {'map_apache <= 71.5': [1, 0]}]}]},
#      {'height <= 175.23': [{'wbc_apache <= 16.85': [1,
#          {'heart_rate_apache <= 39.5': [0, 1]}]},
#        {'map_apache <= 49.5': [0, 1]}]}]},
#    {'bun_apache <= 20.5': [{'wbc_apache <= 6.4': [0,
#        {'map_apache <= 47.0': [1, 0]}]},
#      {'height <= 162.28': [1,
#        {'wbc_apache <= 19.45': [{'heart_rate_apache <= 51.5': [1, 0]},
#          {'temp_apache <= 36.385': [1, 0]}]}]}]}]},
#  {'bmi <= 33.967945665': [{'age <= 32.5': [0,
#      {'map_apache <= 75.5': [{'heart_rate_apache <= 52.5': [{'map_apache <= 68.0': [0,
#            1]},
#          1]},
#        {'apache_4a_hospital_death_prob <= 0.08499999999999999': [{'map_apache <= 183.5': [0,
#            1]},
#          {'temp_apache <= 34.15': [1, 0]}]}]}]},
#    {'age <= 37.5': [0,
#      {'age <= 43.0': [1,
#        {'map_apache <= 67.5': [{'wbc_apache <= 38.650000000000006': [1, 0]},
#          {'heart_rate_apache <= 52.5': [0, 1]}]}]}]}]},
#  {'resprate_apache <= 15.5': [{'bun_apache <= 12.5': [0,
#      {'bmi <= 31.4556553': [{'hematocrit_apache <= 38.95': [1, 0]},
#        {'hematocrit_apache <= 38.0': [{'heart_rate_apache <= 163.5': [1, 0]},
#          {'hematocrit_apache <= 40.400000000000006': [0, 1]}]}]}]},
#    {'bmi <= 32.88157335': [{'bun_apache <= 23.5': [0,
#        {'heart_rate_apache <= 119.5': [{'resprate_apache <= 45.5': [1, 0]},
#          0]}]},
#      {'gcs_verbal_apache <= 4.5': [{'gcs_motor_apache <= 4.5': [{'resprate_apache <= 30.5': [0,
#            1]},
#          1]},
#        {'map_apache <= 76.5': [{'resprate_apache <= 34.5': [1, 0]},
#          {'bmi <= 38.22257293': [0, 1]}]}]}]}]},
#  {'glucose_apache <= 169.5': [{'creatinine_apache <= 1.3050000000000002': [{'glucose_apache <= 66.5': [1,
#        0]},
#      {'resprate_apache <= 50.5': [{'creatinine_apache <= 6.6': [0, 1]}, 0]}]},
#    {'glucose_apache <= 213.5': [{'resprate_apache <= 35.5': [1,
#        {'wbc_apache <= 16.2': [{'wbc_apache <= 15.25': [0, 1]}, 0]}]},
#      1]}]},
#  {'glucose_apache <= 181.0': [{'resprate_apache <= 29.5': [{'glucose_apache <= 150.5': [{'apache_4a_hospital_death_prob <= 0.055': [0,
#          {'glucose_apache <= 112.5': [1, 0]}]},
#        {'bmi <= 26.32208665': [{'resprate_apache <= 8.0': [1, 0]}, 1]}]},
#      {'glucose_apache <= 74.5': [{'age <= 53.5': [0,
#          {'bmi <= 24.470588675': [0, 1]}]},
#        {'creatinine_apache <= 1.8650000000000002': [0,
#          {'creatinine_apache <= 2.115': [1, 0]}]}]}]},
#    {'glucose_apache <= 215.5': [{'resprate_apache <= 32.0': [1,
#        {'creatinine_apache <= 0.995': [1, 0]}]},
#      {'hematocrit_apache <= 38.25': [{'resprate_apache <= 46.5': [{'creatinine_apache <= 10.0': [1,
#            0]},
#          {'creatinine_apache <= 1.38': [0, 1]}]},
#        {'apache_4a_hospital_death_prob <= 0.035': [1,
#          {'map_apache <= 62.5': [1, 0]}]}]}]}]},
#  {'glucose_apache <= 171.0': [0,
#    {'apache_4a_icu_death_prob <= 0.255': [{'glucose_apache <= 222.5': [{'gcs_verbal_apache <= 2.5': [{'sodium_apache <= 133.5': [0,
#            1]},
#          {'apache_4a_hospital_death_prob <= 0.095': [1, 0]}]},
#        1]},
#      {'apache_4a_icu_death_prob <= 0.515': [0, 1]}]}]},
#  {'resprate_apache <= 35.5': [{'map_apache <= 65.5': [{'creatinine_apache <= 0.52': [1,
#        {'bmi <= 20.997403745': [{'resprate_apache <= 33.5': [0, 1]},
#          {'bun_apache <= 6.5': [0, 1]}]}]},
#      {'bun_apache <= 17.5': [0,
#        {'wbc_apache <= 11.405000000000001': [{'creatinine_apache <= 1.03': [1,
#            0]},
#          {'resprate_apache <= 33.5': [1, 0]}]}]}]},
#    {'bun_apache <= 17.5': [0,
#      {'sodium_apache <= 137.5': [{'wbc_apache <= 6.300000000000001': [0,
#          {'wbc_apache <= 12.600000000000001': [1, 0]}]},
#        {'map_apache <= 128.5': [0, 1]}]}]}]},
#  {'resprate_apache <= 31.5': [{'bun_apache <= 22.5': [{'bmi <= 32.159417520000005': [{'height <= 170.1': [{'bun_apache <= 13.5': [0,
#            1]},
#          0]},
#        1]},
#      {'bmi <= 40.77832721': [{'temp_apache <= 36.05': [{'temp_apache <= 34.35': [0,
#            1]},
#          1]},
#        1]}]},
#    {'bmi <= 26.673437149999998': [{'apache_4a_hospital_death_prob <= 0.095': [{'hematocrit_apache <= 28.35': [{'hematocrit_apache <= 24.7': [0,
#            1]},
#          {'sodium_apache <= 149.0': [0, 1]}]},
#        {'hematocrit_apache <= 32.85': [0, {'bmi <= 20.81948753': [0, 1]}]}]},
#      {'hematocrit_apache <= 34.75': [{'height <= 151.15': [0, 1]},
#        {'bun_apache <= 43.0': [0, 1]}]}]}]},
#  {'glucose_apache <= 164.5': [{'age <= 47.5': [{'creatinine_apache <= 9.445': [{'resprate_apache <= 10.5': [{'creatinine_apache <= 3.0149999999999997': [0,
#            1]},
#          0]},
#        1]},
#      {'glucose_apache <= 74.5': [{'bmi <= 22.685591275': [0, 1]},
#        {'bmi <= 29.23715503': [0, {'glucose_apache <= 154.5': [0, 1]}]}]}]},
#    {'glucose_apache <= 221.5': [{'resprate_apache <= 15.5': [1,
#        {'glucose_apache <= 192.5': [{'heart_rate_apache <= 110.5': [1, 0]},
#          0]}]},
#      {'resprate_apache <= 42.5': [{'gcs_motor_apache <= 4.5': [{'sodium_apache <= 138.5': [0,
#            1]},
#          1]},
#        {'map_apache <= 148.5': [{'glucose_apache <= 236.0': [0, 1]}, 0]}]}]}]},
#  {'bmi <= 28.976738155': [0,
#    {'hematocrit_apache <= 37.55': [1,
#      {'creatinine_apache <= 1.025': [{'bmi <= 29.53259889': [1, 0]},
#        {'sodium_apache <= 139.5': [1, {'map_apache <= 89.5': [1, 0]}]}]}]}]},
#  {'glucose_apache <= 172.5': [{'bun_apache <= 21.5': [{'bmi <= 25.711217225': [{'wbc_apache <= 15.135': [{'bmi <= 15.310052695': [1,
#            0]},
#          {'bmi <= 21.601069805': [0, 1]}]},
#        {'gcs_eyes_apache <= 3.5': [{'bmi <= 26.186325605': [1, 0]},
#          {'glucose_apache <= 87.0': [1, 0]}]}]},
#      {'sodium_apache <= 139.5': [{'bmi <= 38.499388725': [{'wbc_apache <= 18.1': [0,
#            1]},
#          1]},
#        {'height <= 175.15': [{'weight <= 68.5': [0, 1]}, 0]}]}]},
#    {'resprate_apache <= 49.0': [{'glucose_apache <= 222.5': [{'resprate_apache <= 31.5': [{'bmi <= 50.979223895000004': [1,
#            0]},
#          {'bun_apache <= 36.5': [1, 0]}]},
#        1]},
#      {'glucose_apache <= 291.5': [0, 1]}]}]},
#  {'glucose_apache <= 211.5': [{'glucose_apache <= 163.5': [{'gcs_motor_apache <= 4.5': [{'apache_4a_hospital_death_prob <= 0.035': [1,
#          0]},
#        {'glucose_apache <= 71.5': [{'apache_4a_hospital_death_prob <= 0.025': [0,
#            1]},
#          0]}]},
#      {'weight <= 58.05': [0,
#        {'glucose_apache <= 171.5': [1,
#          {'creatinine_apache <= 2.24': [0, 1]}]}]}]},
#    {'temp_apache <= 36.849999999999994': [{'creatinine_apache <= 0.55': [1,
#        {'weight <= 122.1': [{'weight <= 113.6': [1, 0]}, 1]}]},
#      1]}]},
#  {'resprate_apache <= 30.5': [1,
#    {'bun_apache <= 34.5': [0,
#      {'height <= 180.15': [{'weight <= 63.199999999999996': [0, 1]}, 0]}]}]},
#  {'resprate_apache <= 29.5': [{'hematocrit_apache <= 37.05': [{'resprate_apache <= 4.5': [{'hematocrit_apache <= 33.85': [{'heart_rate_apache <= 88.5': [1,
#            0]},
#          1]},
#        {'resprate_apache <= 15.5': [{'heart_rate_apache <= 52.5': [0, 1]},
#          {'resprate_apache <= 16.5': [0, 1]}]}]},
#      {'wbc_apache <= 8.350000000000001': [{'temp_apache <= 35.85': [1,
#          {'heart_rate_apache <= 42.5': [1, 0]}]},
#        {'wbc_apache <= 10.35': [{'hematocrit_apache <= 40.849999999999994': [1,
#            0]},
#          0]}]}]},
#    {'temp_apache <= 36.24': [{'height <= 153.2': [0,
#        {'gcs_verbal_apache <= 4.5': [{'gcs_eyes_apache <= 1.5': [0, 1]}, 0]}]},
#      {'sodium_apache <= 134.5': [{'height <= 175.25': [0,
#          {'temp_apache <= 36.685': [0, 1]}]},
#        {'height <= 149.45': [1, 0]}]}]}]},
#  {'bmi <= 31.661747825': [{'resprate_apache <= 31.5': [{'creatinine_apache <= 0.49': [1,
#        {'age <= 64.5': [0, 1]}]},
#      {'creatinine_apache <= 0.38': [1,
#        {'temp_apache <= 36.05': [{'height <= 170.6': [0, 1]}, 0]}]}]},
#    {'bmi <= 33.001034585': [1,
#      {'height <= 187.93': [{'age <= 49.5': [{'weight <= 104.45': [0, 1]},
#          {'bmi <= 33.235055855': [0, 1]}]},
#        0]}]}]},
#  {'bun_apache <= 25.5': [{'bmi <= 30.6577049': [{'creatinine_apache <= 0.585': [{'heart_rate_apache <= 110.0': [0,
#          1]},
#        0]},
#      {'map_apache <= 110.5': [{'creatinine_apache <= 1.105': [{'age <= 53.5': [0,
#            1]},
#          1]},
#        {'bmi <= 31.31363469': [1, 0]}]}]},
#    {'map_apache <= 171.5': [{'resprate_apache <= 15.5': [{'height <= 153.65': [0,
#          {'age <= 86.5': [1, 0]}]},
#        {'bmi <= 24.825457885': [0, {'height <= 180.15': [1, 0]}]}]},
#      0]}]},
#  {'glucose_apache <= 168.5': [{'hematocrit_apache <= 30.05': [{'resprate_apache <= 13.5': [{'bmi <= 27.457203505': [{'glucose_apache <= 95.5': [0,
#            1]},
#          1]},
#        {'resprate_apache <= 43.5': [0, {'height <= 158.75': [0, 1]}]}]},
#      {'bmi <= 28.380645899999998': [{'resprate_apache <= 29.5': [{'temp_apache <= 36.05': [1,
#            0]},
#          0]},
#        0]}]},
#    {'resprate_apache <= 32.5': [{'glucose_apache <= 256.0': [{'resprate_apache <= 13.5': [1,
#          {'hematocrit_apache <= 26.15': [0, 1]}]},
#        1]},
#      {'glucose_apache <= 301.5': [{'apache_4a_hospital_death_prob <= 0.025': [0,
#          {'height <= 162.57999999999998': [1, 0]}]},
#        1]}]}]},
#  {'glucose_apache <= 152.5': [{'age <= 51.5': [{'hematocrit_apache <= 27.7': [1,
#        {'glucose_apache <= 150.5': [0, 1]}]},
#      {'glucose_apache <= 105.5': [{'age <= 84.5': [{'map_apache <= 49.5': [1,
#            0]},
#          {'bmi <= 52.019638465': [0, 1]}]},
#        {'bmi <= 39.860846175000006': [0, 1]}]}]},
#    {'resprate_apache <= 15.5': [{'hematocrit_apache <= 27.25': [1,
#        {'glucose_apache <= 219.5': [{'map_apache <= 69.0': [1, 0]},
#          {'bun_apache <= 46.0': [1, 0]}]}]},
#      {'glucose_apache <= 259.0': [{'resprate_apache <= 23.5': [0,
#          {'apache_4a_icu_death_prob <= 0.54': [1, 0]}]},
#        {'bmi <= 29.118233365000002': [{'resprate_apache <= 37.5': [0, 1]},
#          1]}]}]}]}]

# %% [markdown]
# ## Step4 : Make predictions with the random forest
# > Note: Please print the f1-score of the predictions of each decision tree

# %%
def make_prediction_forest(forest, data):
  """
  This function will use the pre-trained random forest to make the predictions
  args:
  * forest: the random forest
  * data: the data used to predict
  return:
  * y_prediction: the predicted results
  """
  
  y_prediction = []
  for i in range(len(forest)):
      y_prediction.append(make_prediction(forest[i], data))
  return y_prediction

# %%
y_test = make_prediction_forest(forest, x_validation)
y_pred_test_forest = make_prediction_forest(forest, x_test)
bad_result = []
count_good_tree = 0


for i in range(len(forest)):
  score = calculate_score(y_validation, y_test[i])
  if(score < 0.55):
    bad_result.append(1)
  else:
    bad_result.append(0)
    count_good_tree = count_good_tree + 1
  print(score)
y_test_tree = []
y_pred_test = []
for i in range(len(x_validation)):
  y_test_tree.append(0)
for i in range(len(x_test)):
  y_pred_test.append(0)

for i in range(len(x_validation)):
  for j in range(len(forest)):
    if(bad_result[j] == 0):
      y_test_tree[i] += y_test[j][i]
      
        
        

for i in range(len(x_validation)):
  if(y_test_tree[i] >= count_good_tree/2):
    y_test_tree[i] = 1
  else:
    y_test_tree[i] = 0
  


for i in range(len(x_test)):
  for j in range(len(forest)):
    if(bad_result[j] == 0):
      y_pred_test[i] += y_pred_test_forest[j][i]

for i in range(len(x_test)):
  if(y_pred_test[i] >= count_good_tree/2):
    y_pred_test[i] = 1
  else:
    y_pred_test[i] = 0

ans_f1score1 = calculate_score(y_validation, y_test_tree)
print("ans_f1score = ", ans_f1score1)
# Out:
# 0.478515625
# 0.47619047619047616
# 0.6619915848527349
# 0.44337606837606836
# 0.5232862375719519
# 0.6213168424881775
# 0.6791610887996431
# 0.6093750000000001
# 0.551915089986156
# 0.6718817905258583
# 0.6700421940928271
# 0.6701253782965845
# 0.5913389746142359
# 0.5792584631918324
# 0.669811320754717
# 0.49282786885245905
# 0.47175732217573224
# 0.6585475868290482
# 0.6593616007622678
# 0.5567434210526316
# 0.48501664816870144
# 0.6645101663585952
# 0.6058708414872798
# 0.6283146067415731
# 0.6314788397527341
# 0.5226377952755905
# 0.5742574257425743
# 0.673076923076923
# 0.6809651474530831
# 0.6518737672583825
# 0.6456483126110123
# 0.3454301075268817
# 0.535778175313059
# 0.5525560022975302
# 0.5586854460093895
# 0.5316336166194523
# 0.5445489762036526
# 0.6614173228346457
# 0.5457170356111646
# 0.6185022026431718
# 0.5708333333333333
# 0.6348258706467662
# 0.6088677751385589
# 0.651668541432321
# 0.6502095947834187
# 0.6319809069212412
# 0.6683695189442316
# 0.6206361520558572
# 0.4446797247220752
# 0.5731310942578548
# 0.5988175675675675
# 0.6398601398601398
# 0.648539778449144
# 0.6496815286624203
# 0.5657546337157987
# 0.5843575418994412
# 0.6778981147212194
# 0.5428142213319981
# 0.6040049039640376
# 0.6491387126019945
# 0.6549001393404551
# 0.5151515151515151
# 0.5974643423137878
# 0.6207865168539326
# 0.654475457170356
# 0.3134517766497462
# 0.4997470915528579
# 0.5883620689655172
# 0.6736079674060661
# 0.6456310679611651
# 0.5474383301707779
# 0.6123998312948123
# 0.6042446941323346
# 0.4973876698014628
# 0.6442890442890443
# 0.6383601756954612
# 0.6049481245011971
# 0.5633802816901409
# 0.6247600767754319
# 0.5746361746361747
# 0.6144047035766782
# 0.6791199667911996
# 0.5606378514477549
# 0.6602223296278396
# 0.581098901098901
# 0.4544405997693195
# 0.6103430619559652
# 0.6737229636447307
# 0.6858122588941278
# 0.6015748031496063
# 0.6544956640803286
# 0.6694521819870008
# 0.6816027574321413
# 0.6666666666666666
# 0.6616041765543428
# 0.4956616052060737
# 0.6560942455822383
# 0.5951448707909162
# 0.6760804450149764
# 0.6192068800764454
# 0.6584398413397974
# 0.32862644415917847
# 0.6129032258064516
# 0.5677537896187415
# 0.5123152709359606
# 0.4780278670953912
# 0.6290247316845544
# 0.6246276067527309
# 0.638423645320197
# 0.6461675579322639
# 0.38933663980161193
# 0.5043988269794721
# 0.5504950495049505
# 0.6765498652291104
# 0.4364672364672365
# 0.552312528064661
# 0.360969387755102
# 0.5466063348416289
# 0.5752711496746203
# 0.6594301221166893
# 0.6716010907674328
# 0.6882836143536533
# 0.5871717606543263
# 0.6076833527357393
# 0.6858122588941278
# 0.6213683223992502
# 0.6011381272633213
# 0.5939730372720062
# 0.49600000000000005
# 0.6107784431137724
# 0.6865538735529831
# 0.6898326898326899
# 0.5592730276745146
# 0.6622979467016163
# 0.6555863342566944
# 0.6859296482412061
# 0.5691837625491052
# 0.4475743348982785
# 0.6152659984579799
# 0.5211075805719473
# 0.673076923076923
# 0.609278350515464
# 0.6267748478701826
# 0.6074672048435924
# 0.5758073344280241
# 0.5985663082437275
# 0.37726723095526
# 0.6430309350017378
# 0.6520112254443404
# 0.5257985257985258
# 0.4869029275808937
# 0.6361003861003861
# 0.09001636661211129
# 0.6507083536883244
# 0.5797613787008395
# 0.6417359187442291
# 0.5820328975115986
# 0.6851385390428212
# 0.6511817440912796
# 0.6619531595227574
# 0.6563088512241054
# 0.5652784277023866
# 0.408651109846329
# 0.6561969439728353
# 0.6350894151764137
# 0.6294267981014968
# 0.5893294175232501
# 0.6395939086294415
# 0.5348837209302325
# 0.5261669024045262
# 0.5618448637316562
# 0.6684095860566449
# 0.6368159203980099
# 0.6510263929618769
# 0.5543766578249337
# 0.6546629732225301
# 0.5974842767295596
# 0.6207462074620747
# 0.6529044647143543
# 0.6943005181347149
# 0.6033318325078794
# 0.6579561362575829
# 0.5067218200620477
# 0.5244719216898507
# 0.6950019677292404
# 0.5924764890282131
# 0.642512077294686
# 0.664320281566212
# 0.649927571221632
# 0.6593684210526316
# 0.5546910755148742
# 0.6535044422507403
# 0.5718120805369128
# 0.6708701134930644
# 0.6181965881397238
# 0.6908797417271993
# 0.6632075471698115
# 0.6590207322452581
# 0.6642066420664207
# 0.46920492721164614
# 0.6215666327568667
# 0.663888888888889
# 0.5478147987884032
# 0.6469268730372364
# 0.6256362795002314
# 0.5742821473158551
# 0.36809045226130654
# 0.6400686400686402
# 0.5465274625510668
# 0.5500732779677577
# 0.6589434661723819
# 0.5485347985347986
# 0.6204699322978893
# 0.6632462686567164
# 0.5540647198105761
# 0.5314885496183206
# 0.6264225630875803
# 0.4930182599355531
# 0.4428985507246377
# 0.6616470588235295
# 0.6396484374999999
# 0.5900461775269369
# 0.5956140350877194
# 0.556154977930358
# 0.6858661940629154
# 0.5218718209562564
# 0.6563495675921711
# 0.560763888888889
# 0.6658086658086658
# 0.6200578592092575
# 0.6152570480928691
# 0.6044352759154203
# 0.506711409395973
# 0.5693860386879731
# 0.5910224438902744
# 0.670076726342711
# 0.5040286481647269
# 0.636094674556213
# 0.4463611859838275
# 0.6756642766765079
# 0.6214797136038186
# 0.5720453318942256
# 0.5790335790335791
# 0.5543575920934413
# 0.6607888631090487
# 0.5308521057786484
# 0.6032064128256514
# 0.6164729661445175
# 0.6708860759493671
# 0.571041948579161
# 0.6400371574547145
# 0.6412443552433519
# 0.6418047882136281
# 0.5546218487394958
# 0.6923076923076923
# 0.6047244094488189
# 0.6181972789115646
# 0.6022433132010354
# 0.62570281124498
# 0.6146388754241396
# 0.6012631578947369
# 0.5609424558223833
# 0.6419753086419753
# 0.6728232189973615
# 0.5137614678899082
# 0.590215264187867
# 0.5827814569536425
# 0.6420878210439107
# 0.4971458225220551
# 0.4342984409799555
# 0.5999226903749516
# 0.5783132530120482
# 0.5463591135232926
# 0.5930975713677035
# 0.5877466251298027
# 0.6761439360284318
# 0.6281851274050962
# 0.6520894071914481
# 0.6764705882352942
# 0.6010416666666667
# 0.6581702321347291
# 0.6916496945010183
# 0.6425511661113755
# 0.6342660775650467
# 0.6621276595744681
# 0.46742913973147693
# 0.6625980819529206
# 0.3566726511071215
# 0.6430282702443699
# 0.4049440847557387
# 0.35408560311284043
# 0.650709219858156
# 0.5147271849348141
# 0.6799307958477508
# 0.5691906005221931
# 0.6177726038028716
# 0.5977859778597787
# 0.6940088459991959
# 0.6794520547945205
# 0.6379821958456974
# 0.643436754176611
# 0.6098874204601076
# 0.6023029229406555
# 0.5319045299561617
# 0.5650387950707438
# 0.6569664902998236
# 0.6281234688878
# 0.548107615139079
# 0.6437209302325582
# 0.6481312670920693
# 0.583216127519925
# 0.4591520165460186
# 0.6828633405639913
# 0.5272331154684096
# 0.5493670886075949
# 0.5404921700223713
# 0.6012320328542095
# 0.6403481504507305
# 0.6101354741595585
# 0.6262434864992894
# 0.6175752644426363
# 0.6316153580076098
# 0.6650740563784041
# 0.6591910292350821
# 0.6448863636363636
# 0.5351078476365306
# 0.6658426040379068
# 0.6701697655618432
# 0.6438831104507182
# 0.531573986804901
# 0.6218144750254843
# 0.6269652215340639
# 0.5868263473053892
# 0.5818650623119898
# 0.5155642023346304
# 0.5397802197802196
# 0.6205552849488554
# 0.6424770198355104
# 0.6225045372050817
# 0.6271186440677966
# 0.5853920515574651
# 0.6325757575757577
# 0.6244477172312224
# 0.6985482493595219
# 0.6663598711458812
# 0.6929478756022778
# 0.6491994177583698
# 0.6500235515779557
# 0.5553470919324579
# 0.5558128763316349
# 0.6598378147673922
# 0.6385435168738899
# 0.5786758383490973
# 0.6564531104921077
# 0.6460674157303371
# 0.6357176693510184
# 0.5781466113416321
# 0.6370887337986042
# 0.5482142857142858
# 0.5390625
# 0.4514697726012202
# 0.6717014660151045
# 0.6394495412844037
# 0.6379072969251951
# 0.6164098292378176
# 0.617296222664016
# 0.5663872959858843
# 0.6600985221674878
# 0.536701620591039
# 0.6111951588502269
# 0.6015919564306661
# 0.5553983969825554
# 0.4250712250712251
# 0.6889795918367347
# 0.6452886038480513
# 0.6307996051332676
# 0.6728265434691305
# 0.5674226804123712
# 0.6461259628454916
# 0.6022968949383242
# 0.6475037821482602
# 0.4769403824521935
# 0.6079516859587318
# 0.5648727576136836
# 0.5037756202804747
# 0.6269982238010657
# 0.5919938414164742
# 0.39736684619988033
# 0.5661641541038527
# 0.5715506193934216
# 0.6104712041884817
# 0.6586278586278587
# 0.6058536585365855
# 0.6637972262075562
# 0.6807553956834533
# 0.5306691449814126
# 0.6707423580786026
# 0.5564620008587376
# 0.6622691292875988
# 0.5775401069518717
# 0.4
# 0.7184873949579832
# 0.6124638877424681
# 0.6161490683229813
# 0.597027972027972
# 0.5418098510882016
# 0.6364280652019845
# 0.6302561623972933
# 0.5590979782270606
# 0.6571988246816847
# 0.566021867115223
# 0.5757922871324933
# 0.6777623670827555
# 0.491210447011552
# 0.6543033761293391
# 0.6210363495746326
# 0.7034544638851502
# 0.6588785046728971
# 0.564516129032258
# 0.6355394378966455
# 0.552930883639545
# 0.5644891122278056
# 0.6045112781954889
# 0.46913580246913583
# 0.5973308789691671
# 0.5201535508637236
# 0.5154336109750122
# 0.6572470373746581
# 0.43246187363834426
# 0.6716681376875552
# 0.6055900621118012
# 0.621822033898305
# 0.6450980392156862
# 0.5797230906654757
# 0.6079836233367452
# 0.4268096514745308
# 0.6647727272727272
# 0.6658280922431866
# 0.6082164328657313
# 0.6135416666666668
# 0.6454504706409683
# 0.6149452641599239
# 0.6487238979118329
# 0.6669716376944191
# 0.6640860215053763
# 0.48960973137354286
# 0.5990380411018802
# 0.6092827004219409
# 0.5714285714285715
# 0.5696969696969697
# 0.6683354192740927
# 0.6678460858027422
# 0.6228874939642685
# 0.6357354392892399
# 0.5428434657730972
# 0.6429872495446266
# 0.5396825396825398
# 0.45081506464305793
# 0.49038961038961043
# 0.6796518856195607
# 0.617558022199798
# 0.6512543039842597
# 0.607984607984608
# 0.6141960405601159
# 0.624772974936433
# 0.6881166881166881
# 0.30769230769230765
# 0.5831344470962609
# 0.5619448340345956
# 0.6449480642115204
# 0.6720720720720721
# 0.49841700587969245
# 0.5378973105134475
# 0.5821678321678322
# 0.5995457986373959
# 0.322538860103627
# 0.6710650329877474
# 0.6715328467153284
# 0.5556182947487295
# 0.6208311954848641
# 0.5740486015589178
# 0.6648326455754241
# 0.6596810933940775
# 0.6170212765957447
# 0.6733121884911646
# 0.624443344878773
# 0.6421404682274248
# 0.4342857142857142
# 0.6116303219106958
# 0.4882533197139939
# 0.6045241809672387
# 0.6537735849056603
# 0.5637296834901625
# 0.6327532351628737
# 0.6988754685547689
# 0.5522107243650048
# 0.5667425968109339
# 0.599396291504959
# 0.6335529650278763
# 0.6378539493293591
# 0.5931208053691276
# 0.6409890632429862
# 0.5658324265505984
# 0.5542439572793704
# 0.6654257794322942
# 0.6189000774593338
# 0.6213592233009708
# 0.5357657225156024
# 0.6195899772209567
# 0.6493987049028677
# 0.6241799437675726
# 0.6620689655172414
# 0.5921192758253462
# 0.274932614555256
# 0.5148418491484185
# 0.6004765687053216
# 0.5951316443119722
# 0.6001013684744044
# 0.5912408759124088
# 0.5084241823587711
# 0.5805515239477503
# 0.6663677130044843
# 0.6083289404322614
# 0.6834733893557422
# 0.6467931345980127
# 0.6309055118110236
# 0.5369318181818181
# 0.6590257879656161
# 0.5871559633027523
# 0.4444444444444445
# 0.550354609929078
# 0.5906940063091481
# 0.5827272727272728
# 0.6736942980354577
# 0.6705513222770059
# 0.6082474226804123
# 0.5633676668159427
# 0.6051660516605166
# 0.6405100539480137
# 0.5083743842364531
# 0.6544502617801047
# 0.6074380165289256
# 0.6333988212180747
# 0.5410484668644906
# 0.5910623946037099
# 0.5355731225296443
# 0.6215177713736791
# 0.5968539325842697
# ans_f1score =  0.7119113573407202

# %% [markdown]
# ## Step5 : Write the Output File
# Save your predictions from the **random forest** in a csv file, named as **hw2_advanced.csv**

# %%
advanced = []

for i in range(len(y_pred_test)):
  advanced.append(y_pred_test[i])

# %%
advanced_path = 'hw2_advanced.csv'
pd.DataFrame(advanced).to_csv(advanced_path, header = None, index = None)
